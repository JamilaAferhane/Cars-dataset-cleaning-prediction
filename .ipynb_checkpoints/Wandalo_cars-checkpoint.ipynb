# %% [markdown]
# <h1 style="color:red">Part 1: Data preprocessing</h1>

# %% [markdown]
# <h2 style="color: green">Diagnosing data </h2>

# %% [markdown]
# This section involves the diagnostic examination and analysis of data to identify any potential issues, errors, or anomalies that could impact the data accuracy and reliability.

# %% [markdown]
# Our dataset is about cars information scraped form the Wandaloo site. It contains the following columns:
# - `Brand`: The name of the vehicle manufacturer
# - `Model`: The specific type or design of vehicle within the brand
# - `Version`: The specific variation or edition of a vehicle model
# - `Price`: The vehicule's cost
# - `Model year`:The year in which the model was released to the market for sale
# - `Hand`: The number of previous owners a vehicle has had.
# - `Mileage`: how far the vehicle has traveled over its lifetime.
# - `Fuel type`: The fuel that powers the engine to produce the necessary energy for the propulsion of the vehicle.
# - `Transmision`: It specifies if the vehicule is manual or automatic.
# - `Fiscal horsepower`: The measure of the administrative power of a vehicle used in some countries to determine the amount of tax to be paid on the vehicle.
# - `Exterior color`
# - `Vehicule condition`: The current physical state of the vehicle, including its overall appearance and mechanical condition.
# - `Air conditionning`: The type of the air conditionning in the vehicule.
# - `Electric windows`: Refers to electric windows that can be controlled with buttons.
# - `Electric seats`: Refers to electric seats.
# - `On-board computer`:The computerized system in a vehicle
# - `Start & Stop`: The technology of turning off the engine when the vehicle is stationary and then restarting it when the driver is ready to move again.
# - `Cruise control`: The feature in a vehicle that allows the driver to set and maintain a steady speed.
# - `Automatic headlights`: The feature in a vehicle that allows the headlights to turn on and off automatically based on external lighting conditions.
# - `Rain sensor`: The device that is installed on a vehicle's windshield and is designed to automatically activate the windshield wipers when it detects rain or moisture.
# - `Steering wheel controls`: The feature in many modern vehicles that allow the driver to control certain functions of the car without taking their hands off the steering wheel.
# - `Touchscreen display`: The type of electronic visual display
# - `Electric mirrors`: The feature in a vehicule that allow the driver to adjust the side mirrors with the push of a button.
# - `Automatic trunk opening`: The featurethat allows the trunk to open and close automatically.
# - `Hands-free start`: The feature a vehicle that allows the driver to start the engine without physically inserting a key into the ignition.
# - `1/3-2/3 folding rear seat`: is a type of rear seat configuration commonly found in vehicles that allows the rear seat to be folded down in a flexible manner.
# - `Backup camera`: a safety feature in modern vehicles that helps drivers see what is behind their vehicle when backing up.
# - `Bluetooth`
# - `Aluminum wheels`: a popular type of wheel used in modern vehicles.
# - `Leather steering wheel`: a type of steering wheel that is covered in leather
# - `Daytime running lights`: a safety feature found on many modern vehicles that are designed to improve visibility and reduce the risk of accidents during the day.
# - `Roof rails`: The long bars that run along the length of the car's roof.
# - `Roof`: The type of the roof
# - `Airbags`: Safety devices in vehicles designed to inflate rapidly in the event of a collision
# - `ABS`: Anti-lock Braking System
# - `ESP`: Electronic Stability Program. It is a safety feature in vehicles designed to help drivers maintain control of their car during sudden maneuvers
# - `Traction control`: a safety feature in vehicles designed to prevent the wheels from spinning during acceleration on slippery or uneven surfaces
# - `Architecture`: The design and layout of the engine's components, including its cylinders, valves, and pistons.
# - `Engine displacement`: The measure of the total volume of all the cylinders in an internal combustion engine.
# - `City fuel consumption`: the amount of fuel that a vehicle uses while driving in city or urban environments with frequent starts and stops
# - `Highway fuel consumption`: The amount of fuel that a vehicle uses while driving at high speeds on highways or motorways
# - `Maximum speed`: maximun speed of the vehicule
# - `Fuel tank volume`: the amount of fuel that a vehicle's fuel tank can hold

# %%
#### Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn  #Seaborn is a Python data visualization library based on matplotlib
import missingno as msno # Missing data visualization module for Python

import warnings
#"warnings" module in Python to filter out any warnings that might be raised during the execution of the code
warnings.filterwarnings('ignore')

# %%
#### Read the dataset

# Read in the dataset
data = pd.read_csv('wandaloo_cars.csv')


# Set display option to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Show the head
data.head(5)
# Out:
#       Brand           Model        Version       Price  Model year     Hand  \
# 0  MERCEDES   Classe C 2014          220 d  228.000 DH      2014.0  Seconde
# 1  MERCEDES   Classe C 2003        220 CDI   79.000 DH      2003.0  Seconde
# 2  MERCEDES   Classe B 2013    180 d Urban  150.000 DH      2013.0  Seconde
# 3  MERCEDES   Classe E 2006  Autre version  135.000 DH      2006.0  Seconde
# 4  MERCEDES  CLA Coupé 2014        220 CDI  240.000 DH      2014.0  Seconde
#
#       Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 0  144.500 km    Diesel  Automatique              8 cv     Gris foncé
# 1  350.000 km    Diesel     Manuelle              8 cv           Noir
# 2  144.000 km    Diesel     Manuelle              8 cv           Noir
# 3  248.000 km    Diesel  Automatique              9 cv     Gris clair
# 4  103.000 km    Diesel  Automatique              9 cv    Blanc cassé
#
#   Vehicle condition Air conditioning  Electric windows  \
# 0          Très bon    auto. Bi-zone  Electrique AV/AR
# 1          Très bon            auto.  Electrique AV/AR
# 2       Comme neuve         manuelle  Electrique AV/AR
# 3       Comme neuve    auto. Bi-zone  Electrique AV/AR
# 4         Excellent            auto.  Electrique AV/AR
#
#            Electric seats On-board computer Start & Stop Cruise control  \
# 0  Conducteur et Passager               oui          oui            oui
# 1      Tous les passagers               oui          oui            oui
# 2                     non               oui          non            oui
# 3  Conducteur et Passager               oui          non            oui
# 4  Conducteur et Passager               oui          oui            oui
#
#   Automatic headlights Rain sensor Steering wheel controls  \
# 0                  oui         oui                     oui
# 1                  oui         oui                     oui
# 2                  oui         oui                     oui
# 3                  oui         oui                     oui
# 4                  oui         oui                     oui
#
#   Touchscreen display Electric mirrors Automatic trunk opening  \
# 0                 non              non                     non
# 1                 oui              oui                     oui
# 2                 non              non                     non
# 3                 non              oui                     oui
# 4                 non              oui                     non
#
#   Hands-free start 1/3-2/3 folding rear seat Backup camera Bluetooth  \
# 0              oui                       oui           oui       oui
# 1              non                       non           oui       oui
# 2              oui                       oui           oui       oui
# 3              oui                       non           non       oui
# 4              oui                       non           oui       oui
#
#   Aluminum wheels Leather steering wheel Daytime running lights Roof rails  \
# 0             oui                    oui                    oui        non
# 1             oui                    non                    oui        non
# 2             oui                    oui                    oui        non
# 3             oui                    non                    oui        oui
# 4             oui                    non                    oui        non
#
#           Roof Airbags  ABS  ESP Traction control Engine architecture  \
# 0       Rigide     oui  oui  oui              oui                 NaN
# 1       Rigide     oui  oui  oui              oui                 NaN
# 2       Rigide     oui  oui  oui              oui                 NaN
# 3       Rigide     oui  oui  oui              oui                 NaN
# 4  Panoramique     oui  oui  oui              oui                 NaN
#
#   Engine displacement City fuel consumption Highway fuel consumption  \
# 0                 NaN                   NaN                      NaN
# 1                 NaN                   NaN                      NaN
# 2                 NaN                   NaN                      NaN
# 3                 NaN                   NaN                      NaN
# 4                 NaN                   NaN                      NaN
#
#   Maximum speed Fuel tank volume
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN

# %%
#### Rename the columns for better understanding

# Associate to each column its new name
column_map = {
    'Brand': 'Brand',
    'Model': 'Model',
    'Version': 'Version',
    'Price': 'Price',
    'Modèle': 'Model year',
    'Main': 'Hand',
    'Kilométrage': 'Mileage',
    'Carburant': 'Fuel type',
    'Transmision': 'Transmission',
    'Puissance fiscale': 'Fiscal horsepower', 
    'Couleur extérieure': 'Exterior color',
    'Etat du véhicule': 'Vehicle condition',
    'Climatisation': 'Air conditioning',
    'Vitres électriques': 'Electric windows',
    'Sièges électriques': 'Electric seats',
    'Ordinateur de bord': 'On-board computer',
    'Start & Stop': 'Start & Stop',
    'Régulateur de vitesse': 'Cruise control',
    'Allumage auto. des feux': 'Automatic headlights',
    'Détecteur de pluie': 'Rain sensor',
    'Commandes au volant': 'Steering wheel controls',
    'Ecran tactile': 'Touchscreen display',
    'Rétroviseurs électriques': 'Electric mirrors',
    'Ouverture auto. du coffre': 'Automatic trunk opening',
    'Démarrage mains libres': 'Hands-free start',
    'Banquette arrière rabattable 1/3-2/3': '1/3-2/3 folding rear seat',
    'Caméra de recul': 'Backup camera',
    'Bluetooth': 'Bluetooth',
    'Jantes aluminium': 'Aluminum wheels',
    'Volant cuir': 'Leather steering wheel',
    'Feux de jour': 'Daytime running lights',
    'Barres de toit': 'Roof rails',
    'Toit': 'Roof',
    'Airbags': 'Airbags',
    'ABS': 'ABS',
    'ESP': 'ESP',
    'Antipatinage': 'Traction control',
    'Architecture': 'Engine architecture',
    'Cylindrée': 'Engine displacement',
    'Conso. ville': 'City fuel consumption',
    'Conso. route': 'Highway fuel consumption',
    'Vitesse maxi.': 'Maximum speed',
    'Volume du réservoir': 'Fuel tank volume'
}

# Rename the columns using the map
data = data.rename(columns=column_map)

# Write the updated data to the same CSV file
data.to_csv('wandaloo_cars.csv', index=False)

# Show the changes
data.head()
# Out:
#       Brand           Model        Version       Price  Model year     Hand  \
# 0  MERCEDES   Classe C 2014          220 d  228.000 DH      2014.0  Seconde
# 1  MERCEDES   Classe C 2003        220 CDI   79.000 DH      2003.0  Seconde
# 2  MERCEDES   Classe B 2013    180 d Urban  150.000 DH      2013.0  Seconde
# 3  MERCEDES   Classe E 2006  Autre version  135.000 DH      2006.0  Seconde
# 4  MERCEDES  CLA Coupé 2014        220 CDI  240.000 DH      2014.0  Seconde
#
#       Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 0  144.500 km    Diesel  Automatique              8 cv     Gris foncé
# 1  350.000 km    Diesel     Manuelle              8 cv           Noir
# 2  144.000 km    Diesel     Manuelle              8 cv           Noir
# 3  248.000 km    Diesel  Automatique              9 cv     Gris clair
# 4  103.000 km    Diesel  Automatique              9 cv    Blanc cassé
#
#   Vehicle condition Air conditioning  Electric windows  \
# 0          Très bon    auto. Bi-zone  Electrique AV/AR
# 1          Très bon            auto.  Electrique AV/AR
# 2       Comme neuve         manuelle  Electrique AV/AR
# 3       Comme neuve    auto. Bi-zone  Electrique AV/AR
# 4         Excellent            auto.  Electrique AV/AR
#
#            Electric seats On-board computer Start & Stop Cruise control  \
# 0  Conducteur et Passager               oui          oui            oui
# 1      Tous les passagers               oui          oui            oui
# 2                     non               oui          non            oui
# 3  Conducteur et Passager               oui          non            oui
# 4  Conducteur et Passager               oui          oui            oui
#
#   Automatic headlights Rain sensor Steering wheel controls  \
# 0                  oui         oui                     oui
# 1                  oui         oui                     oui
# 2                  oui         oui                     oui
# 3                  oui         oui                     oui
# 4                  oui         oui                     oui
#
#   Touchscreen display Electric mirrors Automatic trunk opening  \
# 0                 non              non                     non
# 1                 oui              oui                     oui
# 2                 non              non                     non
# 3                 non              oui                     oui
# 4                 non              oui                     non
#
#   Hands-free start 1/3-2/3 folding rear seat Backup camera Bluetooth  \
# 0              oui                       oui           oui       oui
# 1              non                       non           oui       oui
# 2              oui                       oui           oui       oui
# 3              oui                       non           non       oui
# 4              oui                       non           oui       oui
#
#   Aluminum wheels Leather steering wheel Daytime running lights Roof rails  \
# 0             oui                    oui                    oui        non
# 1             oui                    non                    oui        non
# 2             oui                    oui                    oui        non
# 3             oui                    non                    oui        oui
# 4             oui                    non                    oui        non
#
#           Roof Airbags  ABS  ESP Traction control Engine architecture  \
# 0       Rigide     oui  oui  oui              oui                 NaN
# 1       Rigide     oui  oui  oui              oui                 NaN
# 2       Rigide     oui  oui  oui              oui                 NaN
# 3       Rigide     oui  oui  oui              oui                 NaN
# 4  Panoramique     oui  oui  oui              oui                 NaN
#
#   Engine displacement City fuel consumption Highway fuel consumption  \
# 0                 NaN                   NaN                      NaN
# 1                 NaN                   NaN                      NaN
# 2                 NaN                   NaN                      NaN
# 3                 NaN                   NaN                      NaN
# 4                 NaN                   NaN                      NaN
#
#   Maximum speed Fuel tank volume
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN

# %%
# Show the head of the data to visually  identify problems

data.head(50)
# Out:
#        Brand                Model                         Version  \
# 0   MERCEDES        Classe C 2014                           220 d
# 1   MERCEDES        Classe C 2003                         220 CDI
# 2   MERCEDES        Classe B 2013                     180 d Urban
# 3   MERCEDES        Classe E 2006                   Autre version
# 4   MERCEDES       CLA Coupé 2014                         220 CDI
# 5   MERCEDES        Classe E 2010  250 CDI BlueEfficiency Classic
# 6   MERCEDES        Classe E 2016                220 d DCT Luxury
# 7   MERCEDES        Classe C 2013              200 d Avantgarde +
# 8   MERCEDES             GLA 2017                     200 d Urban
# 9   MERCEDES       CLA Coupé 2014                         200 CDI
# 10  MERCEDES        Classe C 2005       220 CDI Bluetec Exclusive
# 11  MERCEDES             GLE 2017             250 d 4MATIC Luxury
# 12  MERCEDES       CLS Coupé 2013                          63 AMG
# 13  MERCEDES             CLK 2005              280 Coupé Elegance
# 14  MERCEDES        Classe C 2000                         220 CDI
# 15  MERCEDES        Classe E 2018              220 d DCT AMG line
# 16  MERCEDES       GLC Coupé 2020           220 d 4MATIC AMG line
# 17  MERCEDES        Classe C 2003                  200 Kompressor
# 18  MERCEDES        Classe A 2017              220 d DCT AMG line
# 19  MERCEDES        Classe A 2018                 160 d DCT Style
# 20  MERCEDES        Classe E 1997                   Autre version
# 21  MERCEDES        Classe C 2010                  220 d AMG line
# 22  MERCEDES        Classe B 2015                 180 d BVA Urban
# 23  MERCEDES        Classe A 2013                           180 d
# 24  MERCEDES        Classe E 2012                       350 d DCT
# 25  MERCEDES             190 1988                   Autre version
# 26  MERCEDES        Classe C 2011  220 CDI BlueEfficiency Classic
# 27  MERCEDES        Classe C 2008                         220 CDI
# 28  MERCEDES        Classe A 2011                   Autre version
# 29  MERCEDES        Classe C 2007                           220 d
# 30  MERCEDES        Classe B 2013              180 CDI Pack Sport
# 31  MERCEDES        Classe E 2010            350 d DCT Avantgarde
# 32  MERCEDES        Classe C 2011                 200 CDI Classic
# 33  MERCEDES        Classe A 2000                 160 CDI Classic
# 34  MERCEDES        Classe A 2017                     180 d Style
# 35  MERCEDES        Classe C 2012     350 BlueEfficiency Elegance
# 36  MERCEDES  Classe C Coupé 2018            220 d DCT AMG line +
# 37  MERCEDES        Classe C 2008                350 CDI Elegance
# 38  MERCEDES        Classe C 2017                220 d Avantgarde
# 39  MERCEDES        Classe E 2007                 280 CDI Classic
# 40  MERCEDES        Classe C 2010                         220 CDI
# 41  MERCEDES        Classe C 2018                200 d Avantgarde
# 42  MERCEDES             GLK 2011                         200 CDI
# 43  MERCEDES        Classe A 2014          160 CDI BlueEfficiency
# 44  MERCEDES        Classe C 2003                         220 CDI
# 45  MERCEDES  Classe C Coupé 2016            250 d DCT AMG line +
# 46  MERCEDES        Classe C 2017                  220 d AMG line
# 47  MERCEDES        Classe C 2006                         220 CDI
# 49  MERCEDES           Citan 2012                   Autre version
# 50  MERCEDES        Classe C 2007                         220 CDI
#
#                 Price  Model year      Hand     Mileage Fuel type  \
# 0          228.000 DH      2014.0   Seconde  144.500 km    Diesel
# 1           79.000 DH      2003.0   Seconde  350.000 km    Diesel
# 2          150.000 DH      2013.0   Seconde  144.000 km    Diesel
# 3          135.000 DH      2006.0   Seconde  248.000 km    Diesel
# 4          240.000 DH      2014.0   Seconde  103.000 km    Diesel
# 5   150.000 DH VENDUE      2010.0   Seconde  169.950 km    Diesel
# 6          580.000 DH      2016.0   Seconde   18.000 km    Diesel
# 7          228.000 DH      2013.0  Première  155.000 km    Diesel
# 8   290.000 DH VENDUE      2017.0  Première   67.271 km    Diesel
# 9          240.000 DH      2014.0   Seconde   87.000 km    Diesel
# 10         130.000 DH      2005.0   Seconde  255.000 km    Diesel
# 11  700.000 DH VENDUE      2017.0  Première   48.653 km    Diesel
# 12  290.000 DH VENDUE      2013.0   Seconde   97.911 km    Diesel
# 13          65.000 DH      2005.0   Seconde  220.000 km    Diesel
# 14   60.000 DH VENDUE      2000.0  Première   30.000 km    Diesel
# 15         653.000 DH      2018.0   Seconde   48.000 km    Diesel
# 16         650.000 DH      2020.0  Première        0 km    Diesel
# 17          58.000 DH      2003.0   Seconde  141.000 km   Essence
# 18         300.000 DH      2017.0   Seconde   50.000 km    Diesel
# 19         220.000 DH      2018.0  Première   29.000 km    Diesel
# 20          60.000 DH      1997.0   Seconde  300.000 km    Diesel
# 21         175.000 DH      2010.0   Seconde  190.000 km    Diesel
# 22         185.000 DH      2015.0  Première  148.000 km    Diesel
# 23         185.000 DH      2013.0   Seconde  128.000 km    Diesel
# 24         900.000 DH      2012.0   Seconde  138.000 km    Diesel
# 25          35.000 DH      1988.0   Seconde  400.000 km    Diesel
# 26  220.000 DH VENDUE      2011.0   Seconde   82.490 km    Diesel
# 27         135.000 DH      2008.0  Première  200.000 km    Diesel
# 28          83.000 DH      2011.0  Première  116.000 km   Essence
# 29         142.000 DH      2007.0   Seconde  190.000 km    Diesel
# 30  166.000 DH VENDUE      2013.0  Première  194.519 km    Diesel
# 31         160.000 DH      2010.0  Première  140.000 km    Diesel
# 32         150.000 DH      2011.0   Seconde  180.000 km    Diesel
# 33   40.000 DH VENDUE      2000.0   Seconde  100.000 km    Diesel
# 34         225.000 DH      2017.0   Seconde   77.000 km    Diesel
# 35  170.000 DH VENDUE      2012.0   Seconde  125.747 km    Diesel
# 36         500.000 DH      2018.0  Première   57.000 km    Diesel
# 37         170.500 DH      2008.0   Seconde  140.000 km    Diesel
# 38  330.000 DH VENDUE      2017.0  Première   80.497 km    Diesel
# 39  102.000 DH VENDUE      2007.0   Seconde  349.000 km    Diesel
# 40  180.000 DH VENDUE      2010.0   Seconde  200.000 km    Diesel
# 41  170.000 DH VENDUE      2018.0   Seconde  140.000 km    Diesel
# 42  185.000 DH VENDUE      2011.0   Seconde  185.000 km    Diesel
# 43  190.000 DH VENDUE      2014.0   Seconde  140.000 km    Diesel
# 44   95.000 DH VENDUE      2003.0   Seconde  460.000 km    Diesel
# 45         400.000 DH      2016.0   Seconde   68.000 km    Diesel
# 46         365.000 DH      2017.0  Première  108.000 km    Diesel
# 47          85.000 DH      2006.0  Première  350.000 km    Diesel
# 49         230.000 DH      2012.0   Seconde  140.000 km    Diesel
# 50         135.000 DH      2007.0   Seconde  157.000 km    Diesel
#
#    Transmission Fiscal horsepower Exterior color Vehicle condition  \
# 0   Automatique              8 cv     Gris foncé          Très bon
# 1      Manuelle              8 cv           Noir          Très bon
# 2      Manuelle              8 cv           Noir       Comme neuve
# 3   Automatique              9 cv     Gris clair       Comme neuve
# 4   Automatique              9 cv    Blanc cassé         Excellent
# 5   Automatique              9 cv           Gris          Très bon
# 6   Automatique              8 cv           Noir       Comme neuve
# 7   Automatique              9 cv           Gris       Comme neuve
# 8   Automatique              9 cv           Noir       Comme neuve
# 9      Manuelle              6 cv          Blanc          Très bon
# 10  Automatique              9 cv           Gris         Excellent
# 11  Automatique             12 cv          Blanc       Comme neuve
# 12  Automatique              9 cv           Noir         Excellent
# 13     Manuelle             11 cv     Gris clair         Excellent
# 14     Manuelle              8 cv     Bleu foncé               Bon
# 15  Automatique              8 cv           Noir         Excellent
# 16  Automatique             10 cv  Autre couleur     Not described
# 17     Manuelle             11 cv           Gris          Très bon
# 18  Automatique              9 cv          Blanc       Comme neuve
# 19  Automatique              6 cv           Noir       Comme neuve
# 20     Manuelle              9 cv  Autre couleur         Excellent
# 21  Automatique              9 cv           Noir         Excellent
# 22  Automatique              6 cv           Noir         Excellent
# 23  Automatique              7 cv     Gris clair         Excellent
# 24  Automatique             12 cv           Noir       Comme neuve
# 25     Manuelle              8 cv           Bleu               Bon
# 26     Manuelle              9 cv           Noir         Excellent
# 27  Automatique              9 cv           Noir               Bon
# 28  Automatique              8 cv          Blanc          Très bon
# 29  Automatique              8 cv           Noir         Excellent
# 30  Automatique              7 cv           Noir         Excellent
# 31  Automatique             12 cv           Noir         Excellent
# 32     Manuelle              9 cv           Noir         Excellent
# 33  Automatique              7 cv           Gris           Correct
# 34  Automatique              6 cv           Noir       Comme neuve
# 35  Automatique             12 cv           Noir          Très bon
# 36  Automatique              9 cv          Blanc       Comme neuve
# 37     Manuelle             12 cv           Noir         Excellent
# 38  Automatique              8 cv           Noir       Comme neuve
# 39  Automatique             13 cv     Bleu foncé         Excellent
# 40  Automatique              9 cv          Blanc          Très bon
# 41  Automatique              8 cv           Noir       Comme neuve
# 42  Automatique              8 cv          Blanc         Excellent
# 43     Manuelle              6 cv           Noir         Excellent
# 44  Automatique              9 cv     Gris clair         Excellent
# 45  Automatique              9 cv           Gris         Excellent
# 46  Automatique              8 cv           Noir       Comme neuve
# 47     Manuelle              9 cv     Gris clair          Très bon
# 49     Manuelle              9 cv           Bleu         Excellent
# 50     Manuelle              9 cv     Bleu foncé         Excellent
#
#     Air conditioning  Electric windows          Electric seats  \
# 0      auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 1              auto.  Electrique AV/AR      Tous les passagers
# 2           manuelle  Electrique AV/AR                     non
# 3      auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 4              auto.  Electrique AV/AR  Conducteur et Passager
# 5      auto. Bi-zone  Electrique AV/AR              Conducteur
# 6   auto. Multi-zone  Electrique AV/AR      Tous les passagers
# 7      auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 8              auto.  Electrique AV/AR                     non
# 9              auto.  Electrique AV/AR                     non
# 10             auto.  Electrique AV/AR                     non
# 11     auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 12     auto. Bi-zone  Electrique AV/AR                     NaN
# 13             auto.  Electrique AV/AR  Conducteur et Passager
# 14          manuelle     Electrique AV                     non
# 15    auto. Tri-zone  Electrique AV/AR  Conducteur et Passager
# 16               non                 -                     non
# 17          manuelle  Electrique AV/AR                     non
# 18             auto.  Electrique AV/AR              Conducteur
# 19             auto.  Electrique AV/AR                     non
# 20          manuelle                 -                     non
# 21     auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 22             auto.  Electrique AV/AR                     non
# 23             auto.  Electrique AV/AR                     non
# 24     auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 25               non                 -                     non
# 26          manuelle  Electrique AV/AR  Conducteur et Passager
# 27     auto. Bi-zone  Electrique AV/AR              Conducteur
# 28          manuelle     Electrique AV                     non
# 29               non  Electrique AV/AR  Conducteur et Passager
# 30             auto.  Electrique AV/AR                     non
# 31     auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 32             auto.                 -                     non
# 33               non     Electrique AV                     non
# 34             auto.  Electrique AV/AR                     non
# 35             auto.  Electrique AV/AR                     non
# 36     auto. Bi-zone     Electrique AV  Conducteur et Passager
# 37             auto.  Electrique AV/AR      Tous les passagers
# 38     auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 39             auto.  Electrique AV/AR                     non
# 40             auto.  Electrique AV/AR                     non
# 41             auto.  Electrique AV/AR                     non
# 42     auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 43     auto. Bi-zone  Electrique AV/AR                     non
# 44          manuelle                 -                     non
# 45     auto. Bi-zone     Electrique AV  Conducteur et Passager
# 46     auto. Bi-zone  Electrique AV/AR  Conducteur et Passager
# 47             auto.  Electrique AV/AR  Conducteur et Passager
# 49          manuelle     Electrique AV                     non
# 50             auto.  Electrique AV/AR                     non
#
#    On-board computer Start & Stop Cruise control Automatic headlights  \
# 0                oui          oui            oui                  oui
# 1                oui          oui            oui                  oui
# 2                oui          non            oui                  oui
# 3                oui          non            oui                  oui
# 4                oui          oui            oui                  oui
# 5                oui          non            oui                  oui
# 6                oui          oui            oui                  oui
# 7                oui          oui            oui                  oui
# 8                oui          oui            oui                  oui
# 9                oui          non            oui                  oui
# 10               non          non            oui                  oui
# 11               oui          oui            oui                  oui
# 12               oui          non            oui                  oui
# 13               oui          non            oui                  oui
# 14               non          non            non                  non
# 15               oui          oui            oui                  oui
# 16               oui          oui            oui                  oui
# 17               oui          non            non                  oui
# 18               oui          oui            oui                  oui
# 19               oui          oui            oui                  oui
# 20               non          non            non                  non
# 21               oui          oui            oui                  oui
# 22               oui          oui            oui                  oui
# 23               oui          oui            oui                  oui
# 24               oui          oui            oui                  oui
# 25               non          non            non                  non
# 26               oui          non            oui                  oui
# 27               oui          non            oui                  oui
# 28               non          non            non                  non
# 29               oui          non            oui                  oui
# 30               oui          oui            oui                  oui
# 31               oui          oui            oui                  oui
# 32               oui          non            oui                  oui
# 33               non          non            non                  non
# 34               oui          oui            oui                  oui
# 35               oui          non            oui                  oui
# 36               oui          oui            oui                  oui
# 37               oui          non            oui                  oui
# 38               oui          oui            oui                  oui
# 39               oui          non            oui                  oui
# 40               non          non            oui                  non
# 41               non          non            oui                  oui
# 42               oui          non            oui                  oui
# 43               oui          oui            oui                  oui
# 44               oui          non            oui                  non
# 45               oui          oui            oui                  oui
# 46               oui          oui            oui                  oui
# 47               non          non            oui                  non
# 49               non          non            non                  non
# 50               oui          non            non                  non
#
#    Rain sensor Steering wheel controls Touchscreen display Electric mirrors  \
# 0          oui                     oui                 non              non
# 1          oui                     oui                 oui              oui
# 2          oui                     oui                 non              non
# 3          oui                     oui                 non              oui
# 4          oui                     oui                 non              oui
# 5          oui                     oui                 non              oui
# 6          oui                     oui                 oui              oui
# 7          oui                     oui                 oui              oui
# 8          oui                     oui                 oui              oui
# 9          non                     oui                 non              non
# 10         oui                     non                 non              oui
# 11         oui                     oui                 oui              oui
# 12         oui                     oui                 oui              oui
# 13         oui                     oui                 non              oui
# 14         non                     non                 non              non
# 15         oui                     oui                 oui              oui
# 16         oui                     oui                 oui              oui
# 17         oui                     oui                 non              oui
# 18         oui                     oui                 oui              oui
# 19         oui                     oui                 oui              oui
# 20         non                     non                 non              non
# 21         oui                     oui                 non              oui
# 22         oui                     oui                 non              oui
# 23         oui                     oui                 oui              oui
# 24         oui                     oui                 oui              oui
# 25         non                     non                 non              non
# 26         oui                     oui                 non              oui
# 27         oui                     oui                 non              oui
# 28         non                     non                 non              non
# 29         non                     oui                 non              non
# 30         oui                     oui                 non              oui
# 31         oui                     oui                 oui              oui
# 32         oui                     oui                 non              oui
# 33         non                     non                 non              oui
# 34         oui                     oui                 oui              oui
# 35         oui                     oui                 oui              oui
# 36         oui                     oui                 oui              oui
# 37         oui                     oui                 non              oui
# 38         oui                     oui                 oui              oui
# 39         oui                     oui                 oui              oui
# 40         oui                     oui                 non              non
# 41         oui                     oui                 non              oui
# 42         oui                     oui                 non              oui
# 43         non                     oui                 non              non
# 44         non                     oui                 non              oui
# 45         oui                     oui                 non              oui
# 46         oui                     oui                 oui              oui
# 47         non                     oui                 non              oui
# 49         oui                     non                 non              non
# 50         oui                     non                 oui              non
#
#    Automatic trunk opening Hands-free start 1/3-2/3 folding rear seat  \
# 0                      non              oui                       oui
# 1                      oui              non                       non
# 2                      non              oui                       oui
# 3                      oui              oui                       non
# 4                      non              oui                       non
# 5                      oui              non                       oui
# 6                      oui              oui                       non
# 7                      oui              oui                       oui
# 8                      oui              oui                       oui
# 9                      oui              oui                       non
# 10                     oui              oui                       non
# 11                     oui              oui                       oui
# 12                     oui              non                       oui
# 13                     non              non                       oui
# 14                     non              non                       non
# 15                     oui              oui                       oui
# 16                     oui              oui                       oui
# 17                     non              non                       oui
# 18                     non              oui                       oui
# 19                     oui              oui                       oui
# 20                     non              non                       non
# 21                     oui              non                       oui
# 22                     non              oui                       oui
# 23                     non              oui                       oui
# 24                     oui              oui                       non
# 25                     non              non                       non
# 26                     oui              non                       oui
# 27                     oui              oui                       oui
# 28                     non              non                       non
# 29                     non              oui                       non
# 30                     oui              non                       oui
# 31                     oui              oui                       non
# 32                     non              non                       non
# 33                     non              non                       oui
# 34                     non              oui                       oui
# 35                     oui              oui                       non
# 36                     oui              oui                       oui
# 37                     oui              non                       oui
# 38                     oui              oui                       non
# 39                     oui              oui                       oui
# 40                     non              non                       non
# 41                     non              non                       non
# 42                     non              oui                       non
# 43                     non              oui                       oui
# 44                     non              non                       non
# 45                     oui              oui                       oui
# 46                     oui              oui                       non
# 47                     non              non                       non
# 49                     non              non                       non
# 50                     non              oui                       non
#
#    Backup camera Bluetooth Aluminum wheels Leather steering wheel  \
# 0            oui       oui             oui                    oui
# 1            oui       oui             oui                    non
# 2            oui       oui             oui                    oui
# 3            non       oui             oui                    non
# 4            oui       oui             oui                    non
# 5            oui       oui             oui                    non
# 6            oui       oui             non                    oui
# 7            oui       oui             oui                    oui
# 8            oui       oui             oui                    oui
# 9            oui       oui             oui                    non
# 10           oui       oui             oui                    non
# 11           oui       oui             oui                    oui
# 12           oui       oui             oui                    non
# 13           non       non             oui                    non
# 14           non       non             oui                    non
# 15           oui       oui             oui                    oui
# 16           oui       oui             oui                    non
# 17           non       non             oui                    non
# 18           oui       oui             oui                    oui
# 19           oui       oui             oui                    non
# 20           non       non             oui                    oui
# 21           non       oui             oui                    oui
# 22           oui       oui             oui                    oui
# 23           oui       oui             oui                    oui
# 24           oui       oui             oui                    oui
# 25           non       non             non                    non
# 26           oui       oui             oui                    non
# 27           non       oui             oui                    non
# 28           non       non             non                    non
# 29           non       oui             oui                    oui
# 30           non       oui             oui                    non
# 31           oui       oui             oui                    oui
# 32           non       oui             oui                    non
# 33           non       non             oui                    non
# 34           oui       oui             non                    oui
# 35           non       non             oui                    non
# 36           oui       oui             oui                    oui
# 37           oui       oui             oui                    non
# 38           oui       oui             non                    oui
# 39           non       oui             oui                    non
# 40           non       oui             oui                    non
# 41           non       oui             oui                    non
# 42           non       oui             oui                    non
# 43           oui       oui             oui                    non
# 44           oui       oui             oui                    non
# 45           oui       oui             non                    oui
# 46           oui       oui             oui                    oui
# 47           non       non             oui                    non
# 49           non       non             non                    non
# 50           non       oui             oui                    non
#
#    Daytime running lights Roof rails                 Roof Airbags  ABS  ESP  \
# 0                     oui        non               Rigide     oui  oui  oui
# 1                     oui        non               Rigide     oui  oui  oui
# 2                     oui        non               Rigide     oui  oui  oui
# 3                     oui        oui               Rigide     oui  oui  oui
# 4                     oui        non          Panoramique     oui  oui  oui
# 5                     oui        non               Rigide     oui  oui  oui
# 6                     oui        non  Panoramique ouvrant     oui  oui  oui
# 7                     oui        non               Rigide     oui  oui  oui
# 8                     oui        oui               Rigide     oui  oui  oui
# 9                     non        non               Rigide     oui  oui  oui
# 10                    oui        non  Panoramique ouvrant     oui  oui  oui
# 11                    oui        non  Panoramique ouvrant     oui  oui  oui
# 12                    oui        non               Rigide     oui  oui  oui
# 13                    non        non              Ouvrant     oui  oui  oui
# 14                    non        non               Rigide     oui  oui  oui
# 15                    oui        non  Panoramique ouvrant     oui  oui  oui
# 16                    oui        non               Rigide     oui  oui  oui
# 17                    non        non               Rigide     oui  oui  oui
# 18                    oui        oui  Panoramique ouvrant     oui  oui  oui
# 19                    oui        non               Rigide     oui  oui  oui
# 20                    non        non               Rigide     oui  oui  oui
# 21                    oui        non               Rigide     oui  oui  oui
# 22                    oui        non               Rigide     oui  oui  oui
# 23                    oui        non               Rigide     oui  oui  oui
# 24                    oui        non               Rigide     oui  oui  oui
# 25                    non        non               Rigide     non  non  non
# 26                    oui        non               Rigide     oui  oui  oui
# 27                    non        oui               Rigide     oui  oui  oui
# 28                    non        non               Rigide     oui  oui  oui
# 29                    oui        non               Rigide     oui  oui  oui
# 30                    oui        non               Rigide     oui  oui  oui
# 31                    oui        non               Rigide     oui  oui  oui
# 32                    non        non               Rigide     oui  oui  oui
# 33                    non        non               Rigide     oui  oui  non
# 34                    oui        non               Rigide     oui  oui  oui
# 35                    oui        non  Panoramique ouvrant     oui  oui  oui
# 36                    oui        non  Panoramique ouvrant     oui  oui  oui
# 37                    oui        non  Panoramique ouvrant     oui  oui  oui
# 38                    oui        non               Rigide     oui  oui  oui
# 39                    oui        non               Rigide     oui  oui  oui
# 40                    non        non               Rigide     oui  oui  non
# 41                    oui        oui  Panoramique ouvrant     oui  oui  oui
# 42                    non        oui               Rigide     oui  oui  oui
# 43                    oui        non               Rigide     oui  oui  oui
# 44                    oui        non               Rigide     oui  oui  non
# 45                    oui        non  Panoramique ouvrant     oui  oui  oui
# 46                    oui        non  Panoramique ouvrant     oui  oui  oui
# 47                    non        non               Rigide     oui  oui  non
# 49                    non        non               Rigide     oui  non  non
# 50                    non        non               Rigide     oui  oui  oui
#
#    Traction control Engine architecture Engine displacement  \
# 0               oui       Not specified         2007.43 cm³
# 1               oui       Not specified         2007.43 cm³
# 2               oui       Not specified         2007.43 cm³
# 3               oui       Not specified         2007.43 cm³
# 4               oui       Not specified         2007.43 cm³
# 5               oui       Not specified         2007.43 cm³
# 6               oui       Not specified         2007.43 cm³
# 7               oui       Not specified         2007.43 cm³
# 8               oui       Not specified         2007.43 cm³
# 9               oui       Not specified         2007.43 cm³
# 10              oui       Not specified         2007.43 cm³
# 11              oui       Not specified         2007.43 cm³
# 12              oui       Not specified         2007.43 cm³
# 13              oui       Not specified         2007.43 cm³
# 14              non       Not specified         2007.43 cm³
# 15              oui       Not specified         2007.43 cm³
# 16              oui       Not specified         2007.43 cm³
# 17              oui       Not specified         2007.43 cm³
# 18              oui       Not specified         2007.43 cm³
# 19              oui       Not specified         2007.43 cm³
# 20              oui       Not specified         2007.43 cm³
# 21              oui       Not specified         2007.43 cm³
# 22              oui       Not specified         2007.43 cm³
# 23              oui       Not specified         2007.43 cm³
# 24              oui       Not specified         2007.43 cm³
# 25              non       Not specified         2007.43 cm³
# 26              oui       Not specified         2007.43 cm³
# 27              oui       Not specified         2007.43 cm³
# 28              oui       Not specified         2007.43 cm³
# 29              non       Not specified         2007.43 cm³
# 30              oui       Not specified         2007.43 cm³
# 31              oui       Not specified         2007.43 cm³
# 32              non       Not specified         2007.43 cm³
# 33              non       Not specified         2007.43 cm³
# 34              oui       Not specified         2007.43 cm³
# 35              oui       Not specified         2007.43 cm³
# 36              oui       Not specified         2007.43 cm³
# 37              oui       Not specified         2007.43 cm³
# 38              oui       Not specified         2007.43 cm³
# 39              oui       Not specified         2007.43 cm³
# 40              non       Not specified         2007.43 cm³
# 41              oui       Not specified         2007.43 cm³
# 42              oui       Not specified         2007.43 cm³
# 43              oui       Not specified         2007.43 cm³
# 44              non       Not specified         2007.43 cm³
# 45              oui       Not specified         2007.43 cm³
# 46              oui       Not specified         2007.43 cm³
# 47              non       Not specified         2007.43 cm³
# 49              non       Not specified         2007.43 cm³
# 50              non       Not specified         2007.43 cm³
#
#    City fuel consumption Highway fuel consumption Maximum speed  \
# 0           6,6 l/100 km                      NaN           NaN
# 1           6,6 l/100 km                      NaN           NaN
# 2           6,6 l/100 km                      NaN           NaN
# 3           6,6 l/100 km                      NaN           NaN
# 4           6,6 l/100 km                      NaN           NaN
# 5           6,6 l/100 km                      NaN           NaN
# 6           6,6 l/100 km                      NaN           NaN
# 7           6,6 l/100 km                      NaN           NaN
# 8           6,6 l/100 km                      NaN           NaN
# 9           6,6 l/100 km                      NaN           NaN
# 10          6,6 l/100 km                      NaN           NaN
# 11          6,6 l/100 km                      NaN           NaN
# 12          6,6 l/100 km                      NaN           NaN
# 13          6,6 l/100 km                      NaN           NaN
# 14          6,6 l/100 km                      NaN           NaN
# 15          6,6 l/100 km                      NaN           NaN
# 16          6,6 l/100 km                      NaN           NaN
# 17          6,6 l/100 km                      NaN           NaN
# 18          6,6 l/100 km                      NaN           NaN
# 19          6,6 l/100 km                      NaN           NaN
# 20          6,6 l/100 km                      NaN           NaN
# 21          6,6 l/100 km                      NaN           NaN
# 22          6,6 l/100 km                      NaN           NaN
# 23          6,6 l/100 km                      NaN           NaN
# 24          6,6 l/100 km                      NaN           NaN
# 25          6,6 l/100 km                      NaN           NaN
# 26          6,6 l/100 km                      NaN           NaN
# 27          6,6 l/100 km                      NaN           NaN
# 28          6,6 l/100 km                      NaN           NaN
# 29          6,6 l/100 km                      NaN           NaN
# 30          6,6 l/100 km                      NaN           NaN
# 31          6,6 l/100 km                      NaN           NaN
# 32          6,6 l/100 km                      NaN           NaN
# 33          6,6 l/100 km                      NaN           NaN
# 34          6,6 l/100 km                      NaN           NaN
# 35          6,6 l/100 km                      NaN           NaN
# 36          6,6 l/100 km                      NaN           NaN
# 37          6,6 l/100 km                      NaN           NaN
# 38          6,6 l/100 km                      NaN           NaN
# 39          6,6 l/100 km                      NaN           NaN
# 40          6,6 l/100 km                      NaN           NaN
# 41          6,6 l/100 km                      NaN           NaN
# 42          6,6 l/100 km                      NaN           NaN
# 43          6,6 l/100 km                      NaN           NaN
# 44          6,6 l/100 km                      NaN           NaN
# 45          6,6 l/100 km                      NaN           NaN
# 46          6,6 l/100 km                      NaN           NaN
# 47          6,6 l/100 km                      NaN           NaN
# 49          6,6 l/100 km                      NaN           NaN
# 50          6,6 l/100 km                      NaN           NaN
#
#    Fuel tank volume Sold
# 0               NaN  non
# 1               NaN  non
# 2               NaN  non
# 3               NaN  non
# 4               NaN  non
# 5               NaN  oui
# 6               NaN  non
# 7               NaN  non
# 8               NaN  oui
# 9               NaN  non
# 10              NaN  non
# 11              NaN  oui
# 12              NaN  oui
# 13              NaN  non
# 14              NaN  oui
# 15              NaN  non
# 16              NaN  non
# 17              NaN  non
# 18              NaN  non
# 19              NaN  non
# 20              NaN  non
# 21              NaN  non
# 22              NaN  non
# 23              NaN  non
# 24              NaN  non
# 25              NaN  non
# 26              NaN  oui
# 27              NaN  non
# 28              NaN  non
# 29              NaN  non
# 30              NaN  oui
# 31              NaN  non
# 32              NaN  non
# 33              NaN  oui
# 34              NaN  non
# 35              NaN  oui
# 36              NaN  non
# 37              NaN  non
# 38              NaN  oui
# 39              NaN  oui
# 40              NaN  oui
# 41              NaN  oui
# 42              NaN  oui
# 43              NaN  oui
# 44              NaN  oui
# 45              NaN  non
# 46              NaN  non
# 47              NaN  non
# 49              NaN  non
# 50              NaN  non

# %% [markdown]
# By visually inspecting the data, we can identify several possible issues:
#
# **Data type problems**:
# - **Problem 1**: The `Price` is a string with the 'DH' unit attached to every instance
# - **Problem 2**: The `Mileage` is also a string with the 'km' unit attached to every distance
# - **Problem 3**: The `Fiscal horsepower` is also a sting with the 'cv' unit attached to every value
# - **Problem 4**: The `Model year` is presented as a float whereas it is a date
# - **Problem 5**: The `Exterior Color` is presented by a string since it can be presented by a RGB format
#
# **Missing data problems**:
#
# - **Problem 6**: So much missing data in `Engine architecture`, `Engine displacement`, `City fuel consumption`, `Highway fuel consumption`, `Maximum speed`,and`Fuel tank volume` columns
# - **Problem 7**: Empty rows
# - **Problem 8**: Some colors are not mentioned
#
# **Text/categorical data problems:**
#
# - **Problem 9**: The model year is mentioned in the `model` column and has its own column
# - **Problem 10**: For some vehicules, in the `Price` column there is 'VENDUE' which means that the vehicule was sold. We can make this in an other column

# %%
# Print data types of columns
data.dtypes
# Out:
# Brand                         object
# Model                         object
# Version                       object
# Price                         object
# Model year                   float64
# Hand                          object
# Mileage                       object
# Fuel type                     object
# Transmission                  object
# Fiscal horsepower             object
# Exterior color                object
# Vehicle condition             object
# Air conditioning              object
# Electric windows              object
# Electric seats                object
# On-board computer             object
# Start & Stop                  object
# Cruise control                object
# Automatic headlights          object
# Rain sensor                   object
# Steering wheel controls       object
# Touchscreen display           object
# Electric mirrors              object
# Automatic trunk opening       object
# Hands-free start              object
# 1/3-2/3 folding rear seat     object
# Backup camera                 object
# Bluetooth                     object
# Aluminum wheels               object
# Leather steering wheel        object
# Daytime running lights        object
# Roof rails                    object
# Roof                          object
# Airbags                       object
# ABS                           object
# ESP                           object
# Traction control              object
# Engine architecture           object
# Engine displacement           object
# City fuel consumption         object
# Highway fuel consumption      object
# Maximum speed                 object
# Fuel tank volume              object
# dtype: object

# %% [markdown]
# This confirms our previous observations and show as more data type problems:
# - `Price` is an object not a float
# - `Model year` is a float not a date
# - `Mileage` is an object not a distance
# - `Fiscal horepower` is an object whereas fiscal horsepower is represented as an integer value.
#
# - **Problem 11**: `City fuel consumption` and `Highway fuel consumption` are object not floats as they represent the amount of fuel
# - **Problem 12**: `Maximum speed` is an object not a float
# - **Problem 13**:`Fuel tank volume` is an object not a float since it represents an amount of a liquid

# %%
# Print info of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Brand                      3063 non-null   object
#  1   Model                      3063 non-null   object
#  2   Version                    2180 non-null   object
#  3   Price                      3063 non-null   object
#  4   Model year                 2180 non-null   float64
#  5   Hand                       2180 non-null   object
#  6   Mileage                    2180 non-null   object
#  7   Fuel type                  2166 non-null   object
#  8   Transmission               2180 non-null   object
#  9   Fiscal horsepower          3048 non-null   object
#  10  Exterior color             2180 non-null   object
#  11  Vehicle condition          2180 non-null   object
#  12  Air conditioning           3048 non-null   object
#  13  Electric windows           3048 non-null   object
#  14  Electric seats             3028 non-null   object
#  15  On-board computer          3048 non-null   object
#  16  Start & Stop               3048 non-null   object
#  17  Cruise control             3048 non-null   object
#  18  Automatic headlights       3048 non-null   object
#  19  Rain sensor                3048 non-null   object
#  20  Steering wheel controls    3048 non-null   object
#  21  Touchscreen display        3048 non-null   object
#  22  Electric mirrors           3048 non-null   object
#  23  Automatic trunk opening    2180 non-null   object
#  24  Hands-free start           3048 non-null   object
#  25  1/3-2/3 folding rear seat  3048 non-null   object
#  26  Backup camera              3048 non-null   object
#  27  Bluetooth                  3048 non-null   object
#  28  Aluminum wheels            3048 non-null   object
#  29  Leather steering wheel     3048 non-null   object
#  30  Daytime running lights     3048 non-null   object
#  31  Roof rails                 3048 non-null   object
#  32  Roof                       3048 non-null   object
#  33  Airbags                    3048 non-null   object
#  34  ABS                        3048 non-null   object
#  35  ESP                        3048 non-null   object
#  36  Traction control           3048 non-null   object
#  37  Engine architecture        845 non-null    object
#  38  Engine displacement        845 non-null    object
#  39  City fuel consumption      845 non-null    object
#  40  Highway fuel consumption   845 non-null    object
#  41  Maximum speed              868 non-null    object
#  42  Fuel tank volume           845 non-null    object
# dtypes: float64(1), object(42)
# memory usage: 1.0+ MB

# %% [markdown]
# Showing the data information conrfirms the following problems:
# - Same amount of  missing data in `Engine architecture`, `Engine displacement`, `City fuel consumption`, `Highway fuel consumption`,and`Fuel tank volume` columns. So, they may be related.
# - There is missing values in every column and a lot of them have the same number of missings values, what raises the possibility of the existence of empty rows
# - **Problem 14**:There is more missings in `Model year` than `Model`, so we can fill some missing for this last.

# %%
# Print number of missing values
data.isna().sum()
# Out:
# Brand                          66
# Model                          66
# Version                       949
# Price                          66
# Model year                    949
# Hand                          949
# Mileage                       949
# Fuel type                     963
# Transmission                  949
# Fiscal horsepower              81
# Exterior color                949
# Vehicle condition             949
# Air conditioning               81
# Electric windows               81
# Electric seats                101
# On-board computer              81
# Start & Stop                   81
# Cruise control                 81
# Automatic headlights           81
# Rain sensor                    81
# Steering wheel controls        81
# Touchscreen display            81
# Electric mirrors               81
# Automatic trunk opening       949
# Hands-free start               81
# 1/3-2/3 folding rear seat      81
# Backup camera                  81
# Bluetooth                      81
# Aluminum wheels                81
# Leather steering wheel         81
# Daytime running lights         81
# Roof rails                     81
# Roof                           81
# Airbags                        81
# ABS                            81
# ESP                            81
# Traction control               81
# Engine architecture          2284
# Engine displacement          2284
# City fuel consumption        2284
# Highway fuel consumption     2284
# Maximum speed                2261
# Fuel tank volume             2284
# dtype: int64

# %% [markdown]
# There is so much missing data, we can deal with this by:
# - Remove missing values
# - Imputation: filling in the missing values with a value that represents the missing data.
# - Treat missing values as a separate category

# %%
# Print description of data for all columns
data.describe(include="all")
# Out:
#              Brand Model        Version       Price   Model year     Hand  \
# count         3063  3063           2180        3063  2180.000000     2180
# unique          33  1127            733        1111          NaN        2
# top     VOLKSWAGEN   GLC  Autre version  110.000 DH          NaN  Seconde
# freq           532    24            374          36          NaN     1126
# mean           NaN   NaN            NaN         NaN  2012.002294      NaN
# std            NaN   NaN            NaN         NaN     5.407446      NaN
# min            NaN   NaN            NaN         NaN  1984.000000      NaN
# 25%            NaN   NaN            NaN         NaN  2009.000000      NaN
# 50%            NaN   NaN            NaN         NaN  2013.000000      NaN
# 75%            NaN   NaN            NaN         NaN  2016.000000      NaN
# max            NaN   NaN            NaN         NaN  2022.000000      NaN
#
#            Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# count         2180      2166         2180              3048           2180
# unique         632         4            2                42             23
# top     200.000 km    Diesel     Manuelle              6 cv           Noir
# freq            47      1902         1146               955            617
# mean           NaN       NaN          NaN               NaN            NaN
# std            NaN       NaN          NaN               NaN            NaN
# min            NaN       NaN          NaN               NaN            NaN
# 25%            NaN       NaN          NaN               NaN            NaN
# 50%            NaN       NaN          NaN               NaN            NaN
# 75%            NaN       NaN          NaN               NaN            NaN
# max            NaN       NaN          NaN               NaN            NaN
#
#        Vehicle condition Air conditioning  Electric windows Electric seats  \
# count               2180             3048              3048           3028
# unique                 6                8                 5              5
# top            Excellent    auto. Bi-zone  Electrique AV/AR            non
# freq                 740              946              1935           2006
# mean                 NaN              NaN               NaN            NaN
# std                  NaN              NaN               NaN            NaN
# min                  NaN              NaN               NaN            NaN
# 25%                  NaN              NaN               NaN            NaN
# 50%                  NaN              NaN               NaN            NaN
# 75%                  NaN              NaN               NaN            NaN
# max                  NaN              NaN               NaN            NaN
#
#        On-board computer Start & Stop Cruise control Automatic headlights  \
# count               3048         3048           3048                 3048
# unique                 2            2              2                    2
# top                  oui          non            oui                  oui
# freq                2192         1775           2186                 1742
# mean                 NaN          NaN            NaN                  NaN
# std                  NaN          NaN            NaN                  NaN
# min                  NaN          NaN            NaN                  NaN
# 25%                  NaN          NaN            NaN                  NaN
# 50%                  NaN          NaN            NaN                  NaN
# 75%                  NaN          NaN            NaN                  NaN
# max                  NaN          NaN            NaN                  NaN
#
#        Rain sensor Steering wheel controls Touchscreen display  \
# count         3048                    3048                3048
# unique           2                       2                   2
# top            oui                     oui                 oui
# freq          1590                    2132                1662
# mean           NaN                     NaN                 NaN
# std            NaN                     NaN                 NaN
# min            NaN                     NaN                 NaN
# 25%            NaN                     NaN                 NaN
# 50%            NaN                     NaN                 NaN
# 75%            NaN                     NaN                 NaN
# max            NaN                     NaN                 NaN
#
#        Electric mirrors Automatic trunk opening Hands-free start  \
# count              3048                    2180             3048
# unique                2                       2                2
# top                 oui                     non              non
# freq               2139                    1774             1666
# mean                NaN                     NaN              NaN
# std                 NaN                     NaN              NaN
# min                 NaN                     NaN              NaN
# 25%                 NaN                     NaN              NaN
# 50%                 NaN                     NaN              NaN
# 75%                 NaN                     NaN              NaN
# max                 NaN                     NaN              NaN
#
#        1/3-2/3 folding rear seat Backup camera Bluetooth Aluminum wheels  \
# count                       3048          3048      3048            3048
# unique                         2             2         2              11
# top                          oui           non       oui             oui
# freq                        1655          1706      2116            1429
# mean                         NaN           NaN       NaN             NaN
# std                          NaN           NaN       NaN             NaN
# min                          NaN           NaN       NaN             NaN
# 25%                          NaN           NaN       NaN             NaN
# 50%                          NaN           NaN       NaN             NaN
# 75%                          NaN           NaN       NaN             NaN
# max                          NaN           NaN       NaN             NaN
#
#        Leather steering wheel Daytime running lights Roof rails    Roof  \
# count                    3048                   3048       3048    3048
# unique                      2                      2          2       4
# top                       non                    oui        non  Rigide
# freq                     1830                   1870       2316    2394
# mean                      NaN                    NaN        NaN     NaN
# std                       NaN                    NaN        NaN     NaN
# min                       NaN                    NaN        NaN     NaN
# 25%                       NaN                    NaN        NaN     NaN
# 50%                       NaN                    NaN        NaN     NaN
# 75%                       NaN                    NaN        NaN     NaN
# max                       NaN                    NaN        NaN     NaN
#
#        Airbags   ABS   ESP Traction control Engine architecture  \
# count     3048  3048  3048             3048                 845
# unique      11     2     2                2                  11
# top        oui   oui   oui              oui         4 cylindres
# freq      1922  2704  2235             2094                 549
# mean       NaN   NaN   NaN              NaN                 NaN
# std        NaN   NaN   NaN              NaN                 NaN
# min        NaN   NaN   NaN              NaN                 NaN
# 25%        NaN   NaN   NaN              NaN                 NaN
# 50%        NaN   NaN   NaN              NaN                 NaN
# 75%        NaN   NaN   NaN              NaN                 NaN
# max        NaN   NaN   NaN              NaN                 NaN
#
#        Engine displacement City fuel consumption Highway fuel consumption  \
# count                  845                   845                      845
# unique                  69                    85                       62
# top              1.968 cm³            - l/100 km               - l/100 km
# freq                    84                   121                      121
# mean                   NaN                   NaN                      NaN
# std                    NaN                   NaN                      NaN
# min                    NaN                   NaN                      NaN
# 25%                    NaN                   NaN                      NaN
# 50%                    NaN                   NaN                      NaN
# 75%                    NaN                   NaN                      NaN
# max                    NaN                   NaN                      NaN
#
#        Maximum speed Fuel tank volume
# count            868              845
# unique            98               51
# top         250 km/h         50 litre
# freq              78              144
# mean             NaN              NaN
# std              NaN              NaN
# min              NaN              NaN
# 25%              NaN              NaN
# 50%              NaN              NaN
# 75%              NaN              NaN
# max              NaN              NaN

# %% [markdown]
# There is 1127 models. So, we can anticipate some values since same models are more likely to have similar specifictions.

# %%
# Find types of fuel 
data['Fuel type'].unique()
# Out:
# array(['Diesel', 'Essence', nan, 'Electrique', 'Hybride'], dtype=object)

# %% [markdown]
# - There is no problem with this

# %%
# Find different colors
data['Exterior color'].unique()
# Out:
# array(['Gris foncé', 'Noir', 'Gris clair', 'Blanc cassé', 'Gris', 'Blanc',
#        'Bleu foncé', '-', 'Autre couleur', 'Bleu', nan, 'Beige',
#        'Bleu ciel', 'Marron', 'Bordeau', 'Rouge', "Jaune d'or",
#        'Marron clair', 'Orange', 'Violet', 'Vert foncé', 'Vert', 'Jaune',
#        'Rose'], dtype=object)

# %% [markdown]
# - We can replace all of '-' and 'nan' with 'Autre couleur' since a car has necessary a color

# %%
# Find vehicule conditions
data['Vehicle condition'].unique()
# Out:
# array(['Très bon', 'Comme neuve', 'Excellent', 'Bon', '-', 'Correct', nan],
#       dtype=object)

# %% [markdown]
# **Problem 15**: Some cars do not have a state. We can create a new category for vehicule condition like 'Not described' for '-' and 'nan'

# %%
# Find air conditioning states
data['Air conditioning'].unique()
# Out:
# array(['auto. Bi-zone', 'auto.', 'manuelle', 'auto. Multi-zone',
#        'auto. Tri-zone', 'non', nan, 'تلقاءي.', 'auto. Quadri-zone'],
#       dtype=object)

# %%
# How many values of different room_types do we have?
data['Air conditioning'].value_counts()
# Out:
# auto. Bi-zone        946
# manuelle             926
# auto.                513
# non                  409
# auto. Tri-zone       141
# auto. Multi-zone      59
# auto. Quadri-zone     53
# تلقاءي.                1
# Name: Air conditioning, dtype: int64

# %% [markdown]
# **Problem 16**: There is an uncessary cotergory in Air conditioning: 'تلقاءي.' .It can be replace with 'auto.'

# %%
# Find electric windows and seats categories
print(data['Electric windows'].unique())
print(data['Electric seats'].unique())
# Out:
# ['Electrique AV/AR' 'Electrique AV' '-' nan 'Electrique AR' 'non']
# ['Conducteur et Passager' 'Tous les passagers' 'non' 'Conducteur' nan
#  'Passager']

# %%
# Find aluminum wheels and airbags categories
print(data['Aluminum wheels'].unique())
print(data['Airbags'].unique())
# Out:
# ['oui' 'non' nan '17 pouces' '18 pouces' '19 pouces' '20 pouces'
#  '16 pouces' '21 pouces' '22 pouces' '15 pouces' '14 pouces']
# ['oui' 'non' nan '8.0' '6.0' '10.0' '7.0' '0.0' '2.0' '4.0' '9.0' '1.0']

# %%
# Find duplicates rows' number 
data.duplicated().sum()
# Out:
# 88

# %% [markdown]
# **Problem 17**: There is 88 duplicated row

# %% [markdown]
# <h2 style="color: green">Cleaning data </h2>

# %% [markdown]
# <h2 style="color: blue">To do list: </h2>
#
# _Dealing with missing data:_
#
# - **Task 1**: Eliminate empty rows
# - **Task 2**: Fill some missings if possible
# - **Task 3**: Create some new categories for missings if possible
# - **Task 4**: Eliminate some rows if possible.
#
# <br>
#
# _Text/categorical data problems:_
#
# - **Task 7**: Replace the category `تلقاءي.` in `Air conditioning ` with `auto.`
# - **Task 8**: Drop duplicated rows
#
# <br>
#
# _Dealing with data type problems:_
#
# - **Task 1**: Remove 'DH' or 'DH VENDUE' from `Price` and convert it to `float`and create a column that indicated if a vehicule is sold or not.
# - **Task 2**: Remove `km` from `Mileage` and convert it to `float`
# - **Task 3**: Convert `Maximun speed` to float
# - **Task 4**: Convert `City fuel consumption` and `Highway fuel consumption` to floats
# - **Task 5**: Convert `Fuel tank volume` to floats

# %% [markdown]
# <h2 style="color: blue">Missing and Text/categorical data problems </h2>

# %% [markdown]
# <h3 style="color: purple">Task 8:</h3> Drop duplicated rows

# %%
#Number of entries in the data
print(f'There is {data.shape[0]} entries in our data')

# Number of duplicated rows
print(f'The number of duplicated rows {data.duplicated().sum()}')

# drop duplicated rows
data.drop_duplicates(inplace=True)
# Out:
# There is 3129 entries in our data
# The number of duplicated rows 88

# %% [markdown]
# <h3 style="color: purple">Task 1:</h3> Drop empty rows

# %%
# Since there was some empty rows. So, there still an empty row after droping duplicated rows

# Drop index column
data = data.reset_index(drop=True)

# Drop the empty column
data = data.dropna(subset= data.columns[:], how="all")


# Create boolean mask for rows with 0 non-NaN values
mask = (data.notnull().sum(axis=1) == 0)

# Count number of rows with 0 non-NaN values
n_rows_with_0_non_nan = mask.sum()

print(f"The dataset has {n_rows_with_0_non_nan} empty rows ")
print(f'After removing duplicated and empty rows, we have {data.shape[0]} entries in our data')
# Out:
# The dataset has 0 empty rows
# After removing duplicated and empty rows, we have 3040 entries in our data

# %% [markdown]
# <h3 style="color: purple">Task 4:</h3> Eliminate some rows if possible.

# %%
# Visualize the missingness 
msno.matrix(data)
plt.show()

# %% [markdown]
# We show the rows that have missing values for all columns except the first two columns

# %%
# create a mask for rows with 40 NaN values
mask_empty_rows = data.isna().sum(axis=1) == 40

# select rows with 40 NaN values using boolean indexing
rows_with_40_nans = data[mask]

# Show these rows
rows_with_40_nans
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Version, Price, Model year, Hand, Mileage, Fuel type, Transmission, Fiscal horsepower, Exterior color, Vehicle condition, Air conditioning, Electric windows, Electric seats, On-board computer, Start & Stop, Cruise control, Automatic headlights, Rain sensor, Steering wheel controls, Touchscreen display, Electric mirrors, Automatic trunk opening, Hands-free start, 1/3-2/3 folding rear seat, Backup camera, Bluetooth, Aluminum wheels, Leather steering wheel, Daytime running lights, Roof rails, Roof, Airbags, ABS, ESP, Traction control, Engine architecture, Engine displacement, City fuel consumption, Highway fuel consumption, Maximum speed, Fuel tank volume]
# Index: []

# %%
# Look for columns with Brand 'FIAT' and model '500'

# use boolean indexing to select rows
mask = (data['Brand'] == 'FIAT') & (data['Model'] == '500')
data[mask]
# Out:
#      Brand Model Version               Price  Model year Hand Mileage  \
# 2438  FIAT   500     NaN  136.900 DH * promo         NaN  NaN     NaN
# 2439  FIAT   500     NaN  153.500 DH * promo         NaN  NaN     NaN
# 2440  FIAT   500     NaN  162.900 DH * promo         NaN  NaN     NaN
# 2441  FIAT   500     NaN  162.900 DH * promo         NaN  NaN     NaN
#
#      Fuel type Transmission Fiscal horsepower Exterior color  \
# 2438       NaN          NaN              7 cv            NaN
# 2439       NaN          NaN              7 cv            NaN
# 2440       NaN          NaN               NaN            NaN
# 2441       NaN          NaN              7 cv            NaN
#
#      Vehicle condition Air conditioning Electric windows Electric seats  \
# 2438               NaN         manuelle    Electrique AV            non
# 2439               NaN            auto.    Electrique AV            non
# 2440               NaN              NaN              NaN            NaN
# 2441               NaN            auto.    Electrique AV            non
#
#      On-board computer Start & Stop Cruise control Automatic headlights  \
# 2438               oui          non            non                  non
# 2439               oui          non            non                  non
# 2440               NaN          NaN            NaN                  NaN
# 2441               oui          non            non                  non
#
#      Rain sensor Steering wheel controls Touchscreen display Electric mirrors  \
# 2438         non                     oui                 non              oui
# 2439         non                     oui                 oui              oui
# 2440         NaN                     NaN                 NaN              NaN
# 2441         non                     oui                 oui              oui
#
#      Automatic trunk opening Hands-free start 1/3-2/3 folding rear seat  \
# 2438                     NaN              non                       non
# 2439                     NaN              non                       non
# 2440                     NaN              NaN                       NaN
# 2441                     NaN              non                       non
#
#      Backup camera Bluetooth Aluminum wheels Leather steering wheel  \
# 2438           non       non             non                    non
# 2439           non       oui       15 pouces                    non
# 2440           NaN       NaN             NaN                    NaN
# 2441           non       oui       15 pouces                    oui
#
#      Daytime running lights Roof rails         Roof Airbags  ABS  ESP  \
# 2438                    oui        non       Rigide     8.0  oui  oui
# 2439                    oui        non  Panoramique     8.0  oui  oui
# 2440                    NaN        NaN          NaN     NaN  NaN  NaN
# 2441                    oui        non  Panoramique     8.0  oui  oui
#
#      Traction control Engine architecture Engine displacement  \
# 2438              oui         4 cylindres           1.242 cm³
# 2439              oui         4 cylindres           1.242 cm³
# 2440              NaN                 NaN                 NaN
# 2441              oui         4 cylindres           1.242 cm³
#
#      City fuel consumption Highway fuel consumption Maximum speed  \
# 2438          6,2 l/100 km             4,2 l/100 km      160 km/h
# 2439          6,2 l/100 km             4,2 l/100 km      160 km/h
# 2440                   NaN                      NaN           NaN
# 2441          6,2 l/100 km             4,2 l/100 km      160 km/h
#
#      Fuel tank volume
# 2438         35 litre
# 2439         35 litre
# 2440              NaN
# 2441         35 litre

# %% [markdown]
# Since, there is other rows with the same model '500' and Brand 'FIAT', we can drop the one that has just the Brand and the Model values.
# We check for each row: if there is other rows that have the same brand and model, we drop it

# %%
# Look for columns with Brand 'PORSCHE' and model 'Cayenne'

# use boolean indexing to select rows
mask = (data['Brand'] == 'PORSCHE') & (data['Model'] == 'Cayenne')
data[mask]
# Out:
#         Brand    Model Version                           Price  Model year  \
# 2856  PORSCHE  Cayenne     NaN    961.000 DH *   * Prix public         NaN
# 2857  PORSCHE  Cayenne     NaN  1.370.000 DH *   * Prix public         NaN
# 2858  PORSCHE  Cayenne     NaN  2.350.000 DH *   * Prix public         NaN
# 2859  PORSCHE  Cayenne     NaN  2.460.000 DH *   * Prix public         NaN
#
#      Hand Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 2856  NaN     NaN       NaN          NaN             21 cv            NaN
# 2857  NaN     NaN       NaN          NaN               NaN            NaN
# 2858  NaN     NaN       NaN          NaN               NaN            NaN
# 2859  NaN     NaN       NaN          NaN               NaN            NaN
#
#      Vehicle condition Air conditioning  Electric windows  \
# 2856               NaN    auto. Bi-zone  Electrique AV/AR
# 2857               NaN              NaN               NaN
# 2858               NaN              NaN               NaN
# 2859               NaN              NaN               NaN
#
#               Electric seats On-board computer Start & Stop Cruise control  \
# 2856  Conducteur et Passager               oui          oui            oui
# 2857                     NaN               NaN          NaN            NaN
# 2858                     NaN               NaN          NaN            NaN
# 2859                     NaN               NaN          NaN            NaN
#
#      Automatic headlights Rain sensor Steering wheel controls  \
# 2856                  oui         oui                     oui
# 2857                  NaN         NaN                     NaN
# 2858                  NaN         NaN                     NaN
# 2859                  NaN         NaN                     NaN
#
#      Touchscreen display Electric mirrors Automatic trunk opening  \
# 2856                 oui              oui                     NaN
# 2857                 NaN              NaN                     NaN
# 2858                 NaN              NaN                     NaN
# 2859                 NaN              NaN                     NaN
#
#      Hands-free start 1/3-2/3 folding rear seat Backup camera Bluetooth  \
# 2856              oui                       oui           oui       oui
# 2857              NaN                       NaN           NaN       NaN
# 2858              NaN                       NaN           NaN       NaN
# 2859              NaN                       NaN           NaN       NaN
#
#      Aluminum wheels Leather steering wheel Daytime running lights Roof rails  \
# 2856       20 pouces                    oui                    oui        oui
# 2857             NaN                    NaN                    NaN        NaN
# 2858             NaN                    NaN                    NaN        NaN
# 2859             NaN                    NaN                    NaN        NaN
#
#              Roof Airbags  ABS  ESP Traction control Engine architecture  \
# 2856  Panoramique    10.0  oui  oui              oui    6 cylindres en V
# 2857          NaN     NaN  NaN  NaN              NaN                 NaN
# 2858          NaN     NaN  NaN  NaN              NaN                 NaN
# 2859          NaN     NaN  NaN  NaN              NaN                 NaN
#
#      Engine displacement City fuel consumption Highway fuel consumption  \
# 2856           2.995 cm³            - l/100 km               - l/100 km
# 2857                 NaN                   NaN                      NaN
# 2858                 NaN                   NaN                      NaN
# 2859                 NaN                   NaN                      NaN
#
#      Maximum speed Fuel tank volume
# 2856      253 km/h         90 litre
# 2857           NaN              NaN
# 2858           NaN              NaN
# 2859           NaN              NaN

# %%
# Look for columns with Brand 'PORSCHE' and model 'Cayenne Coupé'

# use boolean indexing to select rows
mask = (data['Brand'] == 'PORSCHE') & (data['Model'] == 'Cayenne Coupé')
data[mask]
# Out:
#         Brand          Model Version                           Price  \
# 2860  PORSCHE  Cayenne Coupé     NaN  1.260.000 DH *   * Prix public
# 2861  PORSCHE  Cayenne Coupé     NaN  1.578.000 DH *   * Prix public
# 2862  PORSCHE  Cayenne Coupé     NaN  2.620.000 DH *   * Prix public
#
#       Model year Hand Mileage Fuel type Transmission Fiscal horsepower  \
# 2860         NaN  NaN     NaN       NaN          NaN             21 cv
# 2861         NaN  NaN     NaN       NaN          NaN               NaN
# 2862         NaN  NaN     NaN       NaN          NaN               NaN
#
#      Exterior color Vehicle condition Air conditioning  Electric windows  \
# 2860            NaN               NaN    auto. Bi-zone  Electrique AV/AR
# 2861            NaN               NaN              NaN               NaN
# 2862            NaN               NaN              NaN               NaN
#
#               Electric seats On-board computer Start & Stop Cruise control  \
# 2860  Conducteur et Passager               oui          oui            oui
# 2861                     NaN               NaN          NaN            NaN
# 2862                     NaN               NaN          NaN            NaN
#
#      Automatic headlights Rain sensor Steering wheel controls  \
# 2860                  oui         oui                     oui
# 2861                  NaN         NaN                     NaN
# 2862                  NaN         NaN                     NaN
#
#      Touchscreen display Electric mirrors Automatic trunk opening  \
# 2860                 oui              oui                     NaN
# 2861                 NaN              NaN                     NaN
# 2862                 NaN              NaN                     NaN
#
#      Hands-free start 1/3-2/3 folding rear seat Backup camera Bluetooth  \
# 2860              oui                       oui           oui       oui
# 2861              NaN                       NaN           NaN       NaN
# 2862              NaN                       NaN           NaN       NaN
#
#      Aluminum wheels Leather steering wheel Daytime running lights Roof rails  \
# 2860       20 pouces                    oui                    oui        oui
# 2861             NaN                    NaN                    NaN        NaN
# 2862             NaN                    NaN                    NaN        NaN
#
#              Roof Airbags  ABS  ESP Traction control Engine architecture  \
# 2860  Panoramique    10.0  oui  oui              oui    6 cylindres en V
# 2861          NaN     NaN  NaN  NaN              NaN                 NaN
# 2862          NaN     NaN  NaN  NaN              NaN                 NaN
#
#      Engine displacement City fuel consumption Highway fuel consumption  \
# 2860           2.995 cm³            - l/100 km               - l/100 km
# 2861                 NaN                   NaN                      NaN
# 2862                 NaN                   NaN                      NaN
#
#      Maximum speed Fuel tank volume
# 2860      253 km/h         90 litre
# 2861           NaN              NaN
# 2862           NaN              NaN

# %%
# Look for columns with Brand 'SEAT' and model 'Ibiza'

# use boolean indexing to select rows
mask = (data['Brand'] == 'SEAT') & (data['Model'] == 'Ibiza')
data[mask]
# Out:
#      Brand  Model Version               Price  Model year Hand Mileage  \
# 2898  SEAT  Ibiza     NaN  192.900 DH * promo         NaN  NaN     NaN
# 2899  SEAT  Ibiza     NaN  229.900 DH * promo         NaN  NaN     NaN
# 2900  SEAT  Ibiza     NaN  242.900 DH * promo         NaN  NaN     NaN
# 2901  SEAT  Ibiza     NaN  147.900 DH * promo         NaN  NaN     NaN
# 2902  SEAT  Ibiza     NaN  163.900 DH * promo         NaN  NaN     NaN
# 2903  SEAT  Ibiza     NaN  164.900 DH * promo         NaN  NaN     NaN
# 2904  SEAT  Ibiza     NaN  171.900 DH * promo         NaN  NaN     NaN
#
#      Fuel type Transmission Fiscal horsepower Exterior color  \
# 2898       NaN          NaN              6 cv            NaN
# 2899       NaN          NaN              6 cv            NaN
# 2900       NaN          NaN               NaN            NaN
# 2901       NaN          NaN              6 cv            NaN
# 2902       NaN          NaN              6 cv            NaN
# 2903       NaN          NaN              6 cv            NaN
# 2904       NaN          NaN              6 cv            NaN
#
#      Vehicle condition Air conditioning  Electric windows Electric seats  \
# 2898               NaN         manuelle  Electrique AV/AR            non
# 2899               NaN    auto. Bi-zone  Electrique AV/AR            non
# 2900               NaN              NaN               NaN            NaN
# 2901               NaN         manuelle  Electrique AV/AR            non
# 2902               NaN    auto. Bi-zone  Electrique AV/AR            non
# 2903               NaN    auto. Bi-zone  Electrique AV/AR            non
# 2904               NaN    auto. Bi-zone  Electrique AV/AR            non
#
#      On-board computer Start & Stop Cruise control Automatic headlights  \
# 2898               oui          non            oui                  non
# 2899               oui          non            oui                  oui
# 2900               NaN          NaN            NaN                  NaN
# 2901               oui          non            oui                  non
# 2902               oui          non            oui                  oui
# 2903               oui          non            oui                  oui
# 2904               oui          non            oui                  oui
#
#      Rain sensor Steering wheel controls Touchscreen display Electric mirrors  \
# 2898         non                     oui                 oui              oui
# 2899         oui                     oui                 oui              oui
# 2900         NaN                     NaN                 NaN              NaN
# 2901         non                     oui                 oui              oui
# 2902         oui                     oui                 oui              oui
# 2903         oui                     oui                 oui              oui
# 2904         oui                     oui                 oui              oui
#
#      Automatic trunk opening Hands-free start 1/3-2/3 folding rear seat  \
# 2898                     NaN              non                       oui
# 2899                     NaN              oui                       oui
# 2900                     NaN              NaN                       NaN
# 2901                     NaN              non                       oui
# 2902                     NaN              non                       oui
# 2903                     NaN              non                       oui
# 2904                     NaN              non                       oui
#
#      Backup camera Bluetooth Aluminum wheels Leather steering wheel  \
# 2898           non       oui       15 pouces                    non
# 2899           oui       oui       18 pouces                    oui
# 2900           NaN       NaN             NaN                    NaN
# 2901           non       oui       15 pouces                    non
# 2902           non       oui       15 pouces                    oui
# 2903           non       oui       15 pouces                    oui
# 2904           oui       oui       15 pouces                    oui
#
#      Daytime running lights Roof rails                 Roof Airbags  ABS  ESP  \
# 2898                    oui        non               Rigide     6.0  oui  oui
# 2899                    oui        non  Panoramique ouvrant     6.0  oui  oui
# 2900                    NaN        NaN                  NaN     NaN  NaN  NaN
# 2901                    oui        non               Rigide     6.0  oui  oui
# 2902                    oui        non               Rigide     6.0  oui  oui
# 2903                    oui        non               Rigide     6.0  oui  oui
# 2904                    oui        non  Panoramique ouvrant     6.0  oui  oui
#
#      Traction control Engine architecture Engine displacement  \
# 2898              oui         4 cylindres           1.598 cm³
# 2899              oui         4 cylindres           1.598 cm³
# 2900              NaN                 NaN                 NaN
# 2901              oui         3 cylindres             999 cm³
# 2902              oui         3 cylindres             999 cm³
# 2903              oui         3 cylindres             999 cm³
# 2904              oui         3 cylindres             999 cm³
#
#      City fuel consumption Highway fuel consumption Maximum speed  \
# 2898          4,4 l/100 km             3,5 l/100 km      182 km/h
# 2899          4,4 l/100 km             3,5 l/100 km      182 km/h
# 2900                   NaN                      NaN           NaN
# 2901          6,0 l/100 km             4,3 l/100 km      167 km/h
# 2902          6,0 l/100 km             4,3 l/100 km      167 km/h
# 2903          6,0 l/100 km             4,3 l/100 km      167 km/h
# 2904          6,0 l/100 km             4,3 l/100 km      167 km/h
#
#      Fuel tank volume
# 2898         40 litre
# 2899         40 litre
# 2900              NaN
# 2901         40 litre
# 2902         40 litre
# 2903         40 litre
# 2904         40 litre

# %%
# Look for columns with Brand 'SKODA' and model 'Karoq'

# use boolean indexing to select rows
mask = (data['Brand'] == 'SKODA') & (data['Model'] == 'Karoq')
data[mask]
# Out:
#       Brand  Model Version                         Price  Model year Hand  \
# 2934  SKODA  Karoq     NaN  289.000 DH *   * Prix public         NaN  NaN
# 2935  SKODA  Karoq     NaN  314.000 DH *   * Prix public         NaN  NaN
# 2936  SKODA  Karoq     NaN  354.000 DH *   * Prix public         NaN  NaN
# 2937  SKODA  Karoq     NaN  369.000 DH *   * Prix public         NaN  NaN
#
#      Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 2934     NaN       NaN          NaN              8 cv            NaN
# 2935     NaN       NaN          NaN              8 cv            NaN
# 2936     NaN       NaN          NaN              8 cv            NaN
# 2937     NaN       NaN          NaN               NaN            NaN
#
#      Vehicle condition Air conditioning  Electric windows Electric seats  \
# 2934               NaN         manuelle  Electrique AV/AR            non
# 2935               NaN            auto.  Electrique AV/AR            non
# 2936               NaN            auto.  Electrique AV/AR            non
# 2937               NaN              NaN               NaN            NaN
#
#      On-board computer Start & Stop Cruise control Automatic headlights  \
# 2934               oui          non            oui                  non
# 2935               oui          non            oui                  oui
# 2936               oui          non            oui                  oui
# 2937               NaN          NaN            NaN                  NaN
#
#      Rain sensor Steering wheel controls Touchscreen display Electric mirrors  \
# 2934         non                     oui                 oui              oui
# 2935         oui                     oui                 oui              oui
# 2936         oui                     oui                 oui              oui
# 2937         NaN                     NaN                 NaN              NaN
#
#      Automatic trunk opening Hands-free start 1/3-2/3 folding rear seat  \
# 2934                     NaN              non                       oui
# 2935                     NaN              oui                       oui
# 2936                     NaN              oui                       oui
# 2937                     NaN              NaN                       NaN
#
#      Backup camera Bluetooth Aluminum wheels Leather steering wheel  \
# 2934           non       oui       17 pouces                    oui
# 2935           oui       oui       17 pouces                    oui
# 2936           oui       oui       18 pouces                    oui
# 2937           NaN       NaN             NaN                    NaN
#
#      Daytime running lights Roof rails                 Roof Airbags  ABS  ESP  \
# 2934                    oui        oui               Rigide     4.0  oui  oui
# 2935                    oui        oui               Rigide     4.0  oui  oui
# 2936                    oui        oui  Panoramique ouvrant     6.0  oui  oui
# 2937                    NaN        NaN                  NaN     NaN  NaN  NaN
#
#      Traction control Engine architecture Engine displacement  \
# 2934              oui         4 cylindres           1.968 cm³
# 2935              oui         4 cylindres           1.968 cm³
# 2936              oui         4 cylindres           1.968 cm³
# 2937              NaN                 NaN                 NaN
#
#      City fuel consumption Highway fuel consumption Maximum speed  \
# 2934          6,5 l/100 km             4,6 l/100 km      188 km/h
# 2935          6,5 l/100 km             4,6 l/100 km      188 km/h
# 2936          6,5 l/100 km             4,6 l/100 km      188 km/h
# 2937                   NaN                      NaN           NaN
#
#      Fuel tank volume
# 2934         55 litre
# 2935         55 litre
# 2936         55 litre
# 2937              NaN

# %%
# Look for columns with Brand 'SUZUKI' and model 'Ignis'

# use boolean indexing to select rows
mask = (data['Brand'] == 'SUZUKI') & (data['Model'] == 'Ignis')
data[mask]
# Out:
#        Brand  Model Version                         Price  Model year Hand  \
# 2954  SUZUKI  Ignis     NaN  126.900 DH *   * Prix public         NaN  NaN
# 2955  SUZUKI  Ignis     NaN  139.900 DH *   * Prix public         NaN  NaN
# 2956  SUZUKI  Ignis     NaN  149.900 DH *   * Prix public         NaN  NaN
#
#      Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 2954     NaN       NaN          NaN               NaN            NaN
# 2955     NaN       NaN          NaN               NaN            NaN
# 2956     NaN       NaN          NaN               NaN            NaN
#
#      Vehicle condition Air conditioning Electric windows Electric seats  \
# 2954               NaN              NaN              NaN            NaN
# 2955               NaN              NaN              NaN            NaN
# 2956               NaN              NaN              NaN            NaN
#
#      On-board computer Start & Stop Cruise control Automatic headlights  \
# 2954               NaN          NaN            NaN                  NaN
# 2955               NaN          NaN            NaN                  NaN
# 2956               NaN          NaN            NaN                  NaN
#
#      Rain sensor Steering wheel controls Touchscreen display Electric mirrors  \
# 2954         NaN                     NaN                 NaN              NaN
# 2955         NaN                     NaN                 NaN              NaN
# 2956         NaN                     NaN                 NaN              NaN
#
#      Automatic trunk opening Hands-free start 1/3-2/3 folding rear seat  \
# 2954                     NaN              NaN                       NaN
# 2955                     NaN              NaN                       NaN
# 2956                     NaN              NaN                       NaN
#
#      Backup camera Bluetooth Aluminum wheels Leather steering wheel  \
# 2954           NaN       NaN             NaN                    NaN
# 2955           NaN       NaN             NaN                    NaN
# 2956           NaN       NaN             NaN                    NaN
#
#      Daytime running lights Roof rails Roof Airbags  ABS  ESP  \
# 2954                    NaN        NaN  NaN     NaN  NaN  NaN
# 2955                    NaN        NaN  NaN     NaN  NaN  NaN
# 2956                    NaN        NaN  NaN     NaN  NaN  NaN
#
#      Traction control Engine architecture Engine displacement  \
# 2954              NaN                 NaN                 NaN
# 2955              NaN                 NaN                 NaN
# 2956              NaN                 NaN                 NaN
#
#      City fuel consumption Highway fuel consumption Maximum speed  \
# 2954                   NaN                      NaN           NaN
# 2955                   NaN                      NaN           NaN
# 2956                   NaN                      NaN           NaN
#
#      Fuel tank volume
# 2954              NaN
# 2955              NaN
# 2956              NaN

# %%
# Look for columns with Brand 'SUZUKI' and model 'Swift'

# use boolean indexing to select rows
mask = (data['Brand'] == 'SUZUKI') & (data['Model'] == 'Swift')
data[mask]
# Out:
#        Brand  Model Version                         Price  Model year Hand  \
# 2957  SUZUKI  Swift     NaN  119.900 DH *   * Prix public         NaN  NaN
# 2958  SUZUKI  Swift     NaN  134.900 DH *   * Prix public         NaN  NaN
# 2959  SUZUKI  Swift     NaN  149.900 DH *   * Prix public         NaN  NaN
#
#      Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 2957     NaN       NaN          NaN               NaN            NaN
# 2958     NaN       NaN          NaN               NaN            NaN
# 2959     NaN       NaN          NaN               NaN            NaN
#
#      Vehicle condition Air conditioning Electric windows Electric seats  \
# 2957               NaN              NaN              NaN            NaN
# 2958               NaN              NaN              NaN            NaN
# 2959               NaN              NaN              NaN            NaN
#
#      On-board computer Start & Stop Cruise control Automatic headlights  \
# 2957               NaN          NaN            NaN                  NaN
# 2958               NaN          NaN            NaN                  NaN
# 2959               NaN          NaN            NaN                  NaN
#
#      Rain sensor Steering wheel controls Touchscreen display Electric mirrors  \
# 2957         NaN                     NaN                 NaN              NaN
# 2958         NaN                     NaN                 NaN              NaN
# 2959         NaN                     NaN                 NaN              NaN
#
#      Automatic trunk opening Hands-free start 1/3-2/3 folding rear seat  \
# 2957                     NaN              NaN                       NaN
# 2958                     NaN              NaN                       NaN
# 2959                     NaN              NaN                       NaN
#
#      Backup camera Bluetooth Aluminum wheels Leather steering wheel  \
# 2957           NaN       NaN             NaN                    NaN
# 2958           NaN       NaN             NaN                    NaN
# 2959           NaN       NaN             NaN                    NaN
#
#      Daytime running lights Roof rails Roof Airbags  ABS  ESP  \
# 2957                    NaN        NaN  NaN     NaN  NaN  NaN
# 2958                    NaN        NaN  NaN     NaN  NaN  NaN
# 2959                    NaN        NaN  NaN     NaN  NaN  NaN
#
#      Traction control Engine architecture Engine displacement  \
# 2957              NaN                 NaN                 NaN
# 2958              NaN                 NaN                 NaN
# 2959              NaN                 NaN                 NaN
#
#      City fuel consumption Highway fuel consumption Maximum speed  \
# 2957                   NaN                      NaN           NaN
# 2958                   NaN                      NaN           NaN
# 2959                   NaN                      NaN           NaN
#
#      Fuel tank volume
# 2957              NaN
# 2958              NaN
# 2959              NaN

# %%
# Look for columns with Brand 'VOLVO' and model 'XC40'

# use boolean indexing to select rows
mask = (data['Brand'] == 'VOLVO') & (data['Model'] == 'XC40')
data[mask]
# Out:
#       Brand Model Version                         Price  Model year Hand  \
# 3026  VOLVO  XC40     NaN  350.000 DH *   * Prix public         NaN  NaN
# 3027  VOLVO  XC40     NaN  410.000 DH *   * Prix public         NaN  NaN
# 3028  VOLVO  XC40     NaN  410.000 DH *   * Prix public         NaN  NaN
# 3029  VOLVO  XC40     NaN  530.000 DH *   * Prix public         NaN  NaN
# 3030  VOLVO  XC40     NaN  560.000 DH *   * Prix public         NaN  NaN
# 3031  VOLVO  XC40     NaN  560.000 DH *   * Prix public         NaN  NaN
#
#      Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 3026     NaN       NaN          NaN               NaN            NaN
# 3027     NaN       NaN          NaN              8 cv            NaN
# 3028     NaN       NaN          NaN              8 cv            NaN
# 3029     NaN       NaN          NaN              8 cv            NaN
# 3030     NaN       NaN          NaN              8 cv            NaN
# 3031     NaN       NaN          NaN              8 cv            NaN
#
#      Vehicle condition Air conditioning  Electric windows Electric seats  \
# 3026               NaN              NaN               NaN            NaN
# 3027               NaN            auto.  Electrique AV/AR     Conducteur
# 3028               NaN            auto.  Electrique AV/AR     Conducteur
# 3029               NaN            auto.  Electrique AV/AR     Conducteur
# 3030               NaN            auto.  Electrique AV/AR     Conducteur
# 3031               NaN            auto.  Electrique AV/AR     Conducteur
#
#      On-board computer Start & Stop Cruise control Automatic headlights  \
# 3026               NaN          NaN            NaN                  NaN
# 3027               oui          oui            oui                  oui
# 3028               oui          oui            oui                  oui
# 3029               oui          oui            oui                  oui
# 3030               oui          oui            oui                  oui
# 3031               oui          oui            oui                  oui
#
#      Rain sensor Steering wheel controls Touchscreen display Electric mirrors  \
# 3026         NaN                     NaN                 NaN              NaN
# 3027         oui                     oui                 oui              oui
# 3028         oui                     oui                 oui              oui
# 3029         oui                     oui                 oui              oui
# 3030         oui                     oui                 oui              oui
# 3031         oui                     oui                 oui              oui
#
#      Automatic trunk opening Hands-free start 1/3-2/3 folding rear seat  \
# 3026                     NaN              NaN                       NaN
# 3027                     NaN              oui                       oui
# 3028                     NaN              oui                       oui
# 3029                     NaN              oui                       oui
# 3030                     NaN              oui                       oui
# 3031                     NaN              oui                       oui
#
#      Backup camera Bluetooth Aluminum wheels Leather steering wheel  \
# 3026           NaN       NaN             NaN                    NaN
# 3027           oui       oui       19 pouces                    oui
# 3028           oui       oui       18 pouces                    oui
# 3029           oui       oui       18 pouces                    oui
# 3030           oui       oui       19 pouces                    oui
# 3031           oui       oui       18 pouces                    oui
#
#      Daytime running lights Roof rails                 Roof Airbags  ABS  ESP  \
# 3026                    NaN        NaN                  NaN     NaN  NaN  NaN
# 3027                    oui        oui               Rigide     7.0  oui  oui
# 3028                    oui        oui               Rigide     7.0  oui  oui
# 3029                    oui        oui               Rigide     7.0  oui  oui
# 3030                    oui        oui  Panoramique ouvrant     7.0  oui  oui
# 3031                    oui        oui  Panoramique ouvrant     7.0  oui  oui
#
#      Traction control Engine architecture Engine displacement  \
# 3026              NaN                 NaN                 NaN
# 3027              oui         3 cylindres           1.477 cm³
# 3028              oui         3 cylindres           1.477 cm³
# 3029              oui         3 cylindres           1.477 cm³
# 3030              oui         3 cylindres           1.477 cm³
# 3031              oui         3 cylindres           1.477 cm³
#
#      City fuel consumption Highway fuel consumption Maximum speed  \
# 3026                   NaN                      NaN           NaN
# 3027          8,3 l/100 km             5,4 l/100 km      200 km/h
# 3028          8,3 l/100 km             5,4 l/100 km      200 km/h
# 3029            - l/100 km               - l/100 km      180 km/h
# 3030            - l/100 km               - l/100 km      180 km/h
# 3031            - l/100 km               - l/100 km      180 km/h
#
#      Fuel tank volume
# 3026              NaN
# 3027         54 litre
# 3028         54 litre
# 3029         54 litre
# 3030         54 litre
# 3031         54 litre

# %% [markdown]
# Since for all the rows with 40 null values, there is a row that has the same brand and model, we drop these rows
# We drop also the rows of SUZUKI even that there is no other rows with the same brand (Because, there is just 6 rows of it. So, it is not going to influence our data)

# %%
# drop rows with 40 NaN values
data = data.drop(mask_empty_rows[mask_empty_rows].index)
print(f'Now, we have {data.shape[0]} entries')
# Out:
# Now, we have 3025 entries

# %% [markdown]
# <h3 style="color: purple">Task 6:</h3> Fill some missings if possible

# %%
# Show the missings
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
# Show the percentage of completeness in columns
msno.bar(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Fill the missings of Version column**

# %%
# Show  different verisons 
data['Version'].value_counts()
# Out:
# Autre version                                  372
# 1.7 CDTi Cosmo                                  32
# 1.5 dCi Authentique                             27
# 220 CDI                                         24
# 1.6 HDi Active                                  16
# 1.9 dCi Dynamique                               15
# 1.5 dCi Explore                                 15
# 1.6 HDi 92 Active                               12
# 2.0 TDI 150 Confortline                         12
# 1.5 dCi 85 Intens                               12
# 1.5 dCi 85 Limited                              12
# 1.6 TDI Highline                                12
# 2.0 TDI Confortline                             11
# 1.9 TDI Confortline                             11
# 1.5 dCi 110 Smart                               11
# 2.0 TDI Highline                                11
# 1.5 dCi 85 Business                             11
# 1.5 dCi 110 Acenta                              10
# 1.1 Urban                                       10
# 1.5 dCi 90 Acenta                               10
# 1.9 TDI Trendline                               10
# 1.6 HDi Access                                   9
# 2.0 TDI 140 Advance                              9
# 1.4 HDi Urban Clim                               9
# 2.0 HDi 150 BVA Allure                           9
# 1.5 dCi 110 Explore                              9
# 1.6 l TDI Copa                                   9
# 1.5 dCi Intens                                   9
# 1.6 TDI Trendline                                9
# 1.9 TDI Stylance                                 8
# 2.0 CDTi Cosmo                                   8
# 1.5 dCi Elegance                                 8
# 1.4 HDi Active                                   8
# 220 d                                            8
# 1.6 HDi 92 Access                                8
# 1.9 SDI Confortline                              8
# 220 d AMG line                                   8
# 1.9 TDI 130 Pack Highline                        8
# 1.2 l Authentique Clim                           7
# 1.6 HDi 92 Allure                                7
# 1.6 CDTi 136 BVA Innovation                      7
# 1.4 D-4D 90 Luxe                                 7
# 1.6 D2 Momentum                                  7
# 1.5 dCi 85 Life                                  7
# 1.5 dCi 110 Intens                               7
# 3.0 V6 TDI 204 Baroudeur+                        7
# 1.5 dCi Expression                               7
# 3.0 l V6 TDI Pullman                             7
# 1.7 CDTi Enjoy                                   7
# 2.0 TDI 110 Trendline                            7
# 1.9 TDI 110 Pack Confort                         7
# 2.0 TDI 143 Style                                6
# 1.6 CDTi 136 Enjoy                               6
# 1.6 dCi 130 GT Line                              6
# 1.5 dCi 85 Design                                6
# 1.4 D-4D Terra                                   6
# 1.6 dCi 130 Acenta++                             6
# 3.0 V6 TDI 204 Confort                           6
# 1.6 HDi Premium                                  6
# 1.6 TDI Reference Copa                           6
# 1.6 CDTi 136 Innovation                          6
# 1.9 dTi RXE                                      6
# 200 d                                            6
# 1.1 Urban Clim                                   6
# 1.5 dCi 110 Visia                                5
# 2.0 TDI Exclusive DSG                            5
# 1.2 Twinport 70 Glam                             5
# 2.0 TDI Carat                                    5
# 2.0 TDI Trendline DSG                            5
# 1.7 CDTi Cosmo Pack                              5
# 2.0 TDI 184 GTD                                  5
# 1.5 dCi 90 Acenta+                               5
# 1.6 HDi 92 Style                                 5
# 1.5 dCi Pack Authentic                           5
# 1.5 dCi 115 Explore                              5
# 1.6 l Trendline                                  5
# 1.5 l dCi Explore                                5
# 2.0 D Pack                                       5
# 2.0 D                                            5
# 1.6 HDi XT - 90 ch                               5
# 1.6 HDi Premium Plus 110                         5
# 1.6 dCi 130 Acenta                               5
# 2.0 TDI 143 Ambition                             5
# 1.6 D                                            5
# 2.0 D-4D Terra Clim                              5
# 1.5 dCi Tekna                                    5
# 1.5 dCi Confort Expression                       5
# 1.9 TDI Pack Pacific                             5
# 1.9 TDI Highline                                 5
# 1.6 TDI 105 Style                                5
# 1.2 l Dynamique                                  4
# S                                                4
# 2.0 TDI Trendline                                4
# 1.4 HDi ONE Line                                 4
# 1.2 l 75 Edition                                 4
# 1.5 l dCi Dynamique                              4
# 1.9 dTi                                          4
# 1.2 Confortline                                  4
# 1.5 dCi GT-line                                  4
# 1.6 HDi 92 White Edition                         4
# 1.4 HDi Trendy                                   4
# 1.5 dCi 110 Intens EDC                           4
# 2.0 TDI Highline DSG                             4
# 1.5 dCi Pack Authentique Clim                    4
# 1.4 l Enjoy                                      4
# 1.2 TDI Trendline Clim                           4
# 1.6 HDi 92 Pack Edition                          4
# 1.6 HDi 75 Like Clim                             4
# 2.0 TDI 150 Highline                             4
# 2.0 TDI 184 DSG Exclusive                        4
# 2.0 TDI 170 Business DSG                         4
# 1.7 DTi                                          4
# 1.6 TDI Highline DSG                             4
# 1.2 l Authentique                                4
# 180 CDI Pack Sport                               4
# 1.4 D-4D Silver+                                 4
# 1.2 l Trendline Clim                             4
# 1.3 GLX                                          4
# 1.9 TDI Pack Chrome                              4
# 220 CDI BlueEfficiency Classic                   4
# 1.9 SDI Stella                                   4
# 180 d                                            4
# 1.4 TDI 105 Copa                                 4
# 220 d DCT Avantgarde                             4
# 2.2 D-4D 150 AT Platinium                        4
# 220 d DCT AMG line                               4
# 2.7 XDI Luxe                                     4
# 1.4 D-4D Sol                                     4
# 1.5 dCi Confort                                  4
# 1.6 l TDI Style                                  4
# 1.9 TDI Ambiente                                 4
# 180 d Urban                                      4
# 2.0 D4 190 AWD Momentum                          3
# 1.4 D-4D 90 Lounge                               3
# 180 d Style                                      3
# 2.0 TDI 150 DSG Exclusive 4x4                    3
# 1.6 VVT-i Terra Clim                             3
# 1.5 dCi 110 EDC Intens                           3
# 2.0 HDi 150 BVA Active                           3
# 1.4 D-4D 90 Lounge+                              3
# 220 d Avantgarde                                 3
# 200 d Avantgarde                                 3
# 1.1 ONE Line                                     3
# 1.0 MPI 75 Active                                3
# 1.4 HDi Access                                   3
# 1.6 HDi Active +                                 3
# 2.0 D2 120 Momentum                              3
# 2.0 l Pack Luxe                                  3
# 1.6 16v RXE                                      3
# 2.2 D-4D Sol (7 places)                          3
# 180 CDI Classic Sport                            3
# 2.0 D-4D 150 AT Silver+                          3
# 1.6 dCi 130 Tekna                                3
# 1.6 e-HDi STT 115 Allure                         3
# 200 CDI                                          3
# 1.0 VVT-i 69 Lounge                              3
# 2.0 TDI 150 DSG Trendline+                       3
# 2.0 TDI GT Sport                                 3
# 1.6 l dCi GT-line                                3
# 2.0 D-4D Pack Luxe                               3
# Diesel                                           3
# 2.0 TDI Business                                 3
# 1.2 l TDI Trendline Clim                         3
# 3.0 l V6 TDI Explore                             3
# 200 d Urban                                      3
# 1.6 R-Design                                     3
# 1.6 HDi Confort Pack                             3
# 1.4 D-4D Gold                                    3
# 2.0 TDI 110 Confort                              3
# 1.6 HDi 75 Style                                 3
# 2.0 TDI 140 Advance DSG                          3
# 2.0 XDI Premium                                  3
# 1.9 D 1 place                                    3
# 1.5 dCi Life                                     3
# 2.0 TDI Confort                                  3
# 2.0 HDi SR                                       3
# 1.6 e-HDi Allure                                 3
# 1.5 dCi 85 Life Clim                             3
# 2.0 D5 235 AWD R-Design                          3
# 2.0 TDI Caratline                                3
# 1.6 MPI Stylance                                 3
# 2.0 TDI 150 Highline DSG                         3
# 2.0 TDI 150 DSG Carat 4x4                        3
# 1.5 dCi 90 Visia                                 3
# Cooper                                           3
# 1.6 l TDI Reference                              3
# 1.2 l 75 Business                                3
# 1.3 CDTi Enjoy                                   3
# 2.0 TDI 143 FR                                   3
# 1.3 CDTi Enjoy Clim                              3
# 1.6 TDI 105 Xcellence                            3
# 1.6 dCi 130 CVT Tekna                            3
# 1.2 Trendline Clim                               3
# 1.0 VVT-i Terra Clim                             3
# 1.9 TDI Reference                                3
# 1.5 dCi 2PLC                                     3
# 2.0 TDI Executive                                3
# 1.4 TDI Sport Clim                               3
# 1.6 TDI 105 Reference +                          3
# 1.5 dCi Visia                                    3
# 1.5 dCi 85 Explore                               3
# 2.0 D Pack Luxe                                  3
# 1.9 dCi Privilège                                3
# 2.0 CDTi 170 BVA Dynamic                         3
# 1.4 HDi Urban                                    3
# 1.6 BlueHDi 120 Pack Edition                     3
# 2.0 l TDI FR                                     3
# 2.0 CDTi Cosmo BVA                               3
# 1.4 TDI 75 Trendline Clim                        3
# 2.0 TDI 150 DSG Confortline                      3
# 1.2 l Reference                                  2
# 1.6 TDI 95 Style +                               2
# 1.6 l dCi Intens                                 2
# 1.2 l MPI Reference Clim                         2
# 2.0 TDI 143 DSG Style+                           2
# 1.5 dCi Life Clim                                2
# 1.5 dCi 110 Life                                 2
# 1.2 l Privilege                                  2
# 1.4 TDI Premium Clim                             2
# 1.6 l Expression                                 2
# 2.0 e-XDI 175 Premium                            2
# 2.0 TDI 150 DSG Confort 4x4                      2
# 3.0 V6 TDI 259 CONFORT+                          2
# 1.5 l dCi Authentique                            2
# 1.5 dCi Dynamique                                2
# 1.6 l Authentique                                2
# 2.0 TDI 177 FR Grand Prix                        2
# 2.0 TDI Executive BVA                            2
# 1.2 l Life                                       2
# 2.2 D-4D Pack Luxe                               2
# 1.6 dCi 160 EDC Explore                          2
# 2.0 TDI 150 DSG Exclusive 4x4 Pack Design        2
# 2.0 dCi Privilege BVA                            2
# 1.4 l D-4D Silver+                               2
# 1.4 D-4D 90 City                                 2
# 1.5 l dCi Intens                                 2
# 2.0 Xdi Premium                                  2
# 1.8 Hybride 122 Dynamic+                         2
# 1.5 dCi 110 EDC Explore                          2
# 1.6 TDI Highline+ DSG                            2
# 1.0 VVT-i 69 City+                               2
# 2.0 TDI Ambition                                 2
# 2.0 TDI Ambition DSG                             2
# 1.2 Reference Clim                               2
# 1.9 TDI Elegance                                 2
# 1.6 l TDI Ambition                               2
# 1.6 TDI 90 Ambition                              2
# 2.0 TDI 110 Highline                             2
# 1.6 TDI Style                                    2
# 2.0 TDI Highline BVA                             2
# 1.0 MPI 75 Reference+                            2
# 1.4 TDI 105 Reference                            2
# 1.6 TDI 105 Reference+                           2
# 3.0 V6 TDI 245 X-TREME                           2
# 1.6 l TDI Reference Clim                         2
# 1.5 dCi 110 Explore+                             2
# 1.9 dTi RTE                                      2
# 2.0 TDI 143 DSG Xcellence                        2
# 2.0 l TDI Ambition                               2
# 2.0 l Sport Edition                              2
# 1.6 TDI Reference                                2
# 2.0 dCi Dynamique                                2
# 1.9 dCi Intens                                   2
# 2.0 dCi Explore                                  2
# 1.6 TDI 95 Style                                 2
# 1.6 dCi 130 Intens                               2
# 4.5 v8 D-4D VX                                   2
# 1.4 TDI Reference Clim                           2
# 1.2 TDI Premium Clim                             2
# 2.0 l Expression                                 2
# 1.2 Authentique                                  2
# 2.0 l TDI Elegance DSG                           2
# 3.0 D-4D Platinium                               2
# 1.9 TDI Tour                                     2
# 2.0 TDI Stylance                                 2
# 1.9 dCi Expression                               2
# 2.0 XDI Luxe                                     2
# 1.4 l Access                                     2
# 2.0 TDI 150 Caratline DSG                        2
# 2.0 CDTi Sport 160 ch                            2
# 1.6 TDI Highline BVA                             2
# 1.0 Confortline                                  2
# 1.2 Confort                                      2
# 1.6 CDTi 136 Dynamic                             2
# 1.5 CTDi 130 Enjoy                               2
# 1.3 CDTi 75 Dynamic                              2
# 2.0 TDI 110 Trendline 7P                         2
# 1.9 TDI GT                                       2
# 2.0 TDI 140 DSG Advance                          2
# 1.4 Sport Clim BVA                               2
# 1.3 CDTi Cosmo                                   2
# 1.6 dCi 130 CVT Acenta++                         2
# 1.8 l Cosmo                                      2
# 1.9 CDTi Cosmo                                   2
# 1.6 l e-HDi Active                               2
# 1.6 HDi Like Clim                                2
# 1.6 HDi Allure                                   2
# 1.6 HDi 75 Pack Edition                          2
# 2.0 HDi Premium                                  2
# 1.2 PureTech 68 Like Clim                        2
# 3.0 l V6 TDI Xtrem                               2
# 2.0 HDi Allure                                   2
# 2.5 dCi Luxe BVA                                 2
# 1.5 dCi 110 Acenta++                             2
# 1.0 MPI 75 Trendline                             2
# 2.0 D5 235 AWD Inscription                       2
# 200 d Avantgarde +                               2
# 180 d BVA Urban                                  2
# 220 d DCT AMG line +                             2
# 350 CDI Elegance                                 2
# 2.0 D4 Momentum                                  2
# 250 CDI BlueEfficiency                           2
# 320 CDI                                          2
# 1.6 E                                            2
# 2.0 D3 R-Design                                  2
# 160 d Style                                      2
# 2.0 D4 R-Design                                  2
# 3.0 V6 TDI 259 ATMOSPHERE                        2
# One Pack                                         2
# 2.0 TDI Advance                                  2
# 3.0 V6 TDI 259 X-TREME                           2
# 3.0 TDI Caratline Tip.                           2
# 2.5 l R5 Confortline                             2
# 2.0 dCi Elegance                                 2
# 1.5 dCi Acenta                                   2
# 1.2 Visia                                        2
# 1.5 dCi 110 Tekna                                2
# 1.5 l dCi Acenta                                 2
# 1.6 TDI Trendline 7 places                       2
# 2.0 TDI Trendline 4x4                            2
# 2.2 HDi GT                                       2
# 1.6 HDi 115 Pack Edition                         2
# 1.1 ONE Line Clim                                2
# 1.0 Sportline (3p)                               2
# Diesel Platinium Edition                         2
# 2.0 HDi 180 EAT8 Allure                          2
# 1.4 HDi Active Clim                              2
# 2.0 TDI 150 Premium                              2
# 2.0 TDI 110 Carat                                2
# 2.0 TDI 170 Business                             2
# 2.0 HDi 150 Allure                               2
# 1.9 SD Confortline                               2
# 1.6 HDi 92 Access+                               2
# 2.0 HDi ST                                       2
# 1.6 TDI Trendline 5P                             2
# Turbo S                                          2
# 2.0 TDI 177 DSG High                             2
# 1.2 TDI Trendline                                2
# 1.0 l 75 Premium Clim                            2
# 2.0 TDI 150 DSG 4x4 Carat                        2
# 1.6 HDi XT                                       2
# 2.0 TDI Luxe 4x2                                 2
# 1.4 l Active                                     2
# 2.0 TDI Caratline BVA                            2
# 2.0 HDi 140 Active                               2
# 1.4 HDi ONE Line Clim                            2
# 1.6 e-HDi STT Allure                             2
# 2.0 TDI 150 Premium DSG                          2
# 1.0 MPI 75 Confort                               2
# 2.0 HDi 163 BVA Allure                           2
# 1.6 HDi 92 Active+                               2
# 2.0 HDi Premium Pack                             2
# 2.0 TDI Confortline DSG                          1
# 1.4 D-4D 90 Gold                                 1
# 1.6 D2 Kinetic                                   1
# 2.0 D-4D Pack Plus                               1
# 1.6 TDI Trendline+                               1
# 2.0 D4 Inscription                               1
# 2.0 D3 Momentum                                  1
# 2.0 D Gold                                       1
# 3.0 D-4D 173 AT Silver                           1
# 2.0 TDI 150 DSG Exclusive Cabriolet              1
# 1.4 D-4D Terra Clim                              1
# 2.0 T8 407 Recharge Inscription                  1
# 2.0 TDI 170 Exclusive DSG                        1
# 2.0 T8 390 Recharge Inscription                  1
# 1.6 l Highline                                   1
# 2.0 TDI GTD                                      1
# 2.0 l FSI Highline                               1
# 1.2 l TDI Highline                               1
# 2.2 D-4D Gold+ 4WD                               1
# 2.0 TDI Executive 4x4 DSG                        1
# 4.5 V8 D-4D 250 VX                               1
# 2.0 TDI 150 R-line DSG                           1
# 1.8 Hybride 122 DYNAMIC+                         1
# 1.0 VVT-i Style                                  1
# 1.0 VVT-i Lounge                                 1
# 2.0 D2 120 BVM Momentum                          1
# 1.4 D-4D Sol MMT                                 1
# 1.4 l Pack                                       1
# 2.0 D3 Kinetic                                   1
# 2.0 l Pack                                       1
# 1.8 Hybride 122 Distinctive                      1
# 1.0 VVT-i 71 Dynamic+                            1
# 2.0 D2 120 R-Design                              1
# 2.0 D3 150 Momentum                              1
# 2.0 D-4D Pack                                    1
# D2                                               1
# 2.0 D2 Cross Country                             1
# 2.4 D5 Summum                                    1
# 2.0 D3 Summum                                    1
# 2.0 D2 120 Cross Country Inscription             1
# D5                                               1
# 2.0 D4 190 AWD R-Design                          1
# 2.0 D4 Summum                                    1
# 2.0 D4 Xenium                                    1
# 1.4 D-4D 90 Gold+                                1
# 3.0 D-4D 173 AT Gold                             1
# 2.5 T                                            1
# 1.4 l Sol                                        1
# 2.0 TDI 150 DSG 4x4 Executive Pack Prestige      1
# 2.0 TDI Highline 7 places                        1
# 2.4 D5 Momentum                                  1
# 2.0 T Momentum                                   1
# 2.4 D4 AWD R-Design                              1
# 2.0 TDI Caratline DSG                            1
# 2.0 TDI 150 DSG Executive 4x4                    1
# 3.0 D-4D 173 AT Platinium                        1
# 1.6 l TDI Highline                               1
# 2.5 Hybride 218 Dynamic+                         1
# 3.0 V6 TDI 259 ELEGANCE                          1
# 1.6 l Highline BVA                               1
# 2.0 TDI Trendline 7 places                       1
# 1.0 l 75 Premium+ Clim                           1
# 1.4 TDI Premium+ Clim                            1
# 3.0 V6 TDI 240 Sport                             1
# 3.0 TDI Confortline                              1
# 2.0 TDI 150 DSG Highline                         1
# 2.0 TDI Exclusive                                1
# 1.0 l 60 Trendline Clim                          1
# 1.6 Confortline                                  1
# 1.4 l Highline DSG                               1
# 2.0 TDI 150 DSG 4x4 Confort                      1
# 2.0 TDI 150 Exclusive DSG                        1
# 1.6 TDI Trendline DSG                            1
# 2.0 TDI Premium 4x2                              1
# 1.6 TDI Edition 30                               1
# 2.0 TDI 150 DSG White Edition                    1
# 2.0 TDI 150 Confortline DSG                      1
# 2.0 TDI 150 DSG Carat                            1
# 3.0 V6 TDI 259 ATMOSPHERE+                       1
# 2.0 TDI 110 Caddy VAN                            1
# 1.2 Premium                                      1
# 2.0 TDI 150 Trendline                            1
# 3.0 l V6 TDI Confort                             1
# 3.0 l V6 TDI Baroudeur                           1
# 2.0 TDI Trend 4x4                                1
# 1.6 l TDI Trendline                              1
# 2.0 TDI Luxe 4x4 DSG                             1
# 1.0 l Premium Clim                               1
# 3.0 V6 TDI 259 CONFORT                           1
# 1.6 DDis                                         1
# 4.5 v8 D-4D GX                                   1
# 3.0 l V6 TDI Explore+                            1
# 1.2 Premium Clim                                 1
# 1.4 TDI Trendline                                1
# 1.4 D-4D 90 Silver+                              1
# 2.0 TDI Sportline                                1
# 1.9 D Standard                                   1
# 3.0 D-4D Gold AT                                 1
# 1.2 l Trendline                                  1
# 3.0 l V6 TDI X'trem                              1
# 2.5 l R5 Confortline Tip.                        1
# 1.4 l D-4D Gold                                  1
# 2.0 TDI 170 GTD                                  1
# 1.4 l D-4D Silver                                1
# 1.4 TDI 75 Premium+ Clim                         1
# 1.4 l Terra                                      1
# 1.2 Trendline                                    1
# 2.2 D-4D Pack Luxe Limited                       1
# 2.0 TDI Business DSG                             1
# 2.0 TDI 150 DSG Exclusive                        1
# 2.0 l FSI Confortline                            1
# 1.4 l D-4D Sol                                   1
# 2.0 TDI Executive 4x4                            1
# 2.0 TDI 150 DSG Advance                          1
# 3.0 V6 TDI 204 Carat                             1
# 4.2 D (6 places)                                 1
# 1.4 l TFSI Sportline                             1
# 1.4 l Highline                                   1
# 3.0 D                                            1
# 2.0 TDI 150 DSG Trendline                        1
# 4.2 D GX (5 places)                              1
# 1.8 Hybride 122 Distinctive+                     1
# 1.5 dCi 90 Intens EDC                            1
# 1.9 DDiS 129                                     1
# 1.5 l dCi Luxe (5 places)                        1
# 2.0 l Turbo Cosmo Pack BVA                       1
# 1.7 CDTi Pack +                                  1
# 1.5 CDTi 122 Edition                             1
# 1.4 l Twinport OPC Line                          1
# 1.5 CDTi 122 BVA Elegance                        1
# 1.4 l Pack +                                     1
# 1.4 l JAM                                        1
# 2.0 CDTi Essentia                                1
# 1.4 Twinport OPC Line                            1
# 1.6 CDTi Innovation                              1
# 1.5 D 102 GS line                                1
# 1.6 CDTi 92 Elegance                             1
# 1.6 Confort                                      1
# 1.5 dCi Acenta 17                                1
# 1.1 GL Clim                                      1
# 2.5 dCi XE                                       1
# 1.6 l Elegance                                   1
# 2.5 dCi Visia                                    1
# 1.6 l dCi Acenta CVT                             1
# 2.0 dCi Elegance 4WD                             1
# 1.5 dCi 90 Tekna                                 1
# 2.0 dCi Platinium                                1
# 1.6 l dCi Acenta                                 1
# 1.0 DIG-T 117 Tekna                              1
# 1.2 Elegance                                     1
# 2.0 l Pack Confort                               1
# 1.5 dCi 90 Visia+                                1
# 1.6 dCi 130 CVT Acenta                           1
# 2.0 CDTi Sport                                   1
# 1.2 l 70 Enjoy                                   1
# 1.4 l Twinport GLAM                              1
# 1.6 CDTi Dynamic                                 1
# 1.6 HDi Access Clim                              1
# 2.0 HDi 150 BVA GT-line                          1
# 1.9 D XR Clim                                    1
# 1.6 e-HDi 92 Active                              1
# 1.6 HDi 92 Style EVO                             1
# 1.8 SR                                           1
# 1.6 THP Active                                   1
# 1.9 TD 150 Double Cabine 4x4 Active              1
# 2.0 HDi Active                                   1
# 2.0 Blue HDi STT Feline                          1
# 1.2 VTi Access                                   1
# 2.0 HDi 163 BVA Active                           1
# 1.6 HDi 92 Outdoor                               1
# 1.5 BlueHDi 100 Active                           1
# 1.6 e-HDi 92 Allure                              1
# 1.5 BlueHDi 110 Allure Pack+                     1
# 1.1 Trendy                                       1
# 1.6 HDi 75 Access Clim                           1
# 1.6 l Premium Pack                               1
# 1.4 HDi XS Line                                  1
# 1.6 l THP                                        1
# 2.0 CDTi Edition                                 1
# 1.2 l Enjoy Clim                                 1
# 1.3 CDTi Enjoy Clim +                            1
# 1.3 CDTi 75 Enjoy                                1
# 1.3 CDTi 75 Cosmo                                1
# 1.6 CDTi 92 Innovation                           1
# DC 4X4 DI-D Pack Luxe                            1
# 1.1 Pack luxe                                    1
# 2.2 DI-D Intense 2WD                             1
# 150 Classic                                      1
# 220 CDI Bluetec Avantgarde                       1
# 350 d Avantgarde                                 1
# 170 Classic                                      1
# 250 CDI Elegance                                 1
# 200 Coupé Elegance                               1
# 220 CDI Bluetec Classic                          1
# 200 d DCT Urban                                  1
# 220 d AMG line Plus                              1
# 2.5 D                                            1
# 220 d Style                                      1
# 250 d DCT AMG line +                             1
# 160 CDI BlueEfficiency                           1
# 280 CDI Classic                                  1
# 350 BlueEfficiency Elegance                      1
# 160 CDI Classic                                  1
# 200 CDI Classic                                  1
# 350 d DCT Avantgarde                             1
# 350 d DCT                                        1
# 160 d DCT Style                                  1
# 200 Kompressor                                   1
# 220 d 4MATIC AMG line                            1
# 280 Coupé Elegance                               1
# 63 AMG                                           1
# 250 d 4MATIC Luxury                              1
# 220 CDI Bluetec Exclusive                        1
# 220 d DCT Luxury                                 1
# 250 CDI BlueEfficiency Classic                   1
# 300 CDI V6 BlueTEC                               1
# 220 d Luxury                                     1
# 2.5 DI-D Pack                                    1
# 220 d DCT                                        1
# 2.2 DI-D Instyle 4WD BA                          1
# 1.5 l EX                                         1
# 2.2 DI-D Instyle 2WD                             1
# 3.2 DI-D GLS                                     1
# Cooper D ALL4 Chili                              1
# Cooper S                                         1
# Cooper Pack                                      1
# Cooper D Chili                                   1
# Cooper SD ALL4 Chili                             1
# Cooper D Pack                                    1
# 1.6 One Pack                                     1
# 1.4 Pack                                         1
# 1.6 Cooper Pepper                                1
# One D Pack                                       1
# One                                              1
# Cooper D Pepper                                  1
# Cooper S Mayfair                                 1
# Cooper SD Chili                                  1
# ML 250 CDI Blue TEC 4MATIC                       1
# 280 CDI                                          1
# 180 CDI Urban                                    1
# 350 d L AMG line Plus                            1
# 200 CGI BlueEfficiency Classic                   1
# 180 CDI Classic                                  1
# ML 350 CDI Blue TEC 4MATIC                       1
# 350 CDI BlueEfficiency                           1
# 200 CDI BlueEfficiency Classic                   1
# 2.2 l BVA Premium Pack Griffe                    1
# 1.6 l XT                                         1
# 1.9 D XR                                         1
# 1.6 TDI Ambition Sport                           1
# 2.0 TDI 177 DSG Style                            1
# 2.0 TDI 150 DSG Active                           1
# 2.0 l TDI Special Edition                        1
# 2.0 TDI 143 DSG Special Edition                  1
# 1.4 l TDI Copa                                   1
# 1.4 Reference Clim                               1
# 1.4 Stylance Clim                                1
# 2.0 TDI 143 DSG Style                            1
# 2.0 TDI Reference                                1
# 1.6 MPI Reference                                1
# 1.6 TDI 105 Black Line                           1
# 1.4 l Style                                      1
# 1.4 TDI Reference                                1
# 1.0 l MPI Reference                              1
# 1.9 TDI Stella                                   1
# 1.4 l TDI Style                                  1
# 2.0 TDI FR                                       1
# 1.4 l MPI Style                                  1
# 1.4 l Reference                                  1
# 2.0 TDI 143 DSG FR Anniversary                   1
# 1.4 MPI Reference                                1
# 1.6 TDI Entry                                    1
# 1.4 TDI 105 Style                                1
# 1.6 TDI 95 Reference+                            1
# 1.2 l MPI Reference                              1
# 1.0 MPI 75 Urban                                 1
# 1.4 TDI 105 Reference+                           1
# 2.0 TDI 150 DSG Style                            1
# 2.0 TDI Elegance 4x2                             1
# 1.5 l dCi Expression                             1
# 1.0 MPI 75 Ambition                              1
# 1.0 l 67 GA Clim                                 1
# 1.0 l 67 GL Clim                                 1
# 1.6 VVt GL                                       1
# 1.0 l 67 GLX                                     1
# 2.0 XDI Premium Plus                             1
# 2.0 e-XDI Premium Plus BVA                       1
# 2.0 e-XDI Luxe BVA                               1
# 2.7 XDI Premium (7 places)                       1
# 2.7 XDI Premium                                  1
# 2.0 e-XDI 155 Premium                            1
# 2.0 e-XDI Luxe 4x4 BVA                           1
# 2.0 e-XDI Premium                                1
# 2.0 Xdi Luxe BVA                                 1
# 2.0 XDI Luxe BVA                                 1
# 2.0 l TDI Style DSG                              1
# 2.0 TDI 177 Style                                1
# 1.4 TDI Ambiente                                 1
# 2.0 TDI Experience+ 4x4                          1
# 2.0 l TDI Elegance                               1
# 2.0 TDI 150 DSG Ambition                         1
# 1.4 TDI Classic                                  1
# 1.2 l Classic                                    1
# 2.0 TDI 143 Ambition+                            1
# 1.9 TDI Ambition                                 1
# 2.0 TDI Experience+ 4x4 DSG                      1
# 2.0 TDI 143 DSG L&K Edition Limitée              1
# 1.6 l TDI Active                                 1
# 2.0 T Privilege BVA                              1
# 1.2 l Expression                                 1
# 2.0 l Confort Pack                               1
# 1.5 dCi Collection                               1
# 1.5 dCi Generique                                1
# 1.6 dCi L2H1 Combi 9P                            1
# 1.5 dCi 115 EDC Intens                           1
# 1.2 l Collection                                 1
# S Diesel                                         1
# 4S                                               1
# Turbo                                            1
# Carrera 4S                                       1
# 3.0 v6 TDI                                       1
# Carrera 4S Cabriolet                             1
# Carrera Cabriolet                                1
# Diesel 3.0 v6                                    1
# 3.6 V6                                           1
# 1.6 HDi XT - 110 ch                              1
# 1.6 HDi Trendy                                   1
# 1.6 HDi Premium Plus                             1
# 1.4 XR Clim                                      1
# 1.6 HDi 115 Access                               1
# 1.6 HDi XR                                       1
# 1.2 PureTech 68 Like                             1
# 1.6 e-HDi Active                                 1
# 1.4 VTi Active                                   1
# 1.5 BlueHDi 130 BVA Allure                       1
# 1.2 PureTech Allure                              1
# 1.6 HDi 75 Like                                  1
# 2.0 l Premium                                    1
# 1.0 VTi 68 Active                                1
# 1.2 l 75 Design                                  1
# 1.5 dCi 85 GT Line                               1
# 1.5 dCi Extreme                                  1
# 1.5 dCi 85 EDC Ultimate                          1
# 1.5 l dCi Explore EDC                            1
# 1.4 Pack Authentic Clim                          1
# 1.5 dCi Extrem                                   1
# 2.0 dCi Monaco GP                                1
# 1.4 Extreme                                      1
# 1.6 dCi L1H1                                     1
# 2.0 dCi 175 X-Tronic Explore                     1
# 1.5 dCi Business                                 1
# 1.5 l dCi Intens EDC                             1
# 1.5 dCi 85 Limited EDC                           1
# 1.5 dCi 1PLC                                     1
# 1.5 dCi Authentique Clim                         1
# 1.5 dCi 90 EDC Intens                            1
# 1.6 dCi 130 Explore                              1
# 1.6 dCi Intens                                   1
# 1.5 dCi 110 Explore EDC                          1
# 2.0 dCi Life                                     1
# 1.9 dCi Bose Edition                             1
# 1.5 dCi 85 Express                               1
# 1.0 Sce 75 Life                                  1
# 1.5 dCi 115 Life                                 1
# 1.5 dCi 115 Intens                               1
# 2.5 l Privilege                                  1
# 1.6 dCi L2H1                                     1
# 1.5 dCi Exception                                1
# 1.5 dCi Privilege                                1
# 1.5 dCi Storm                                    1
# 2.0 D4 190 Momentum Confort                      1
# Name: Version, dtype: int64

# %% [markdown]
# There are some cars where the version is not specified, but it is set to 'Autre version'. So, we can fill the nan values of 'Version' column with 'Autre version' since every car has a version

# %%
#Print the number of missings in 'Version' column
version_missings = data['Version'].isna().sum()
print( f'There are {version_missings} missings in Version column')

# Give to empty 'Version' cells the string 'Autre version'
data = data.fillna({'Version':'Autre version'})

# Verify all the missings are filled 
version_missings = data['Version'].isna().sum()
print(f'There are still {version_missings} missings')
# Out:
# There are 849 missings in Version column
# There are still 0 missings

# %% [markdown]
# **Fill the missings of Model year column**

# %%
# Describe the Model year column
data['Model year'].describe()
# Out:
# count    2176.000000
# mean     2012.005974
# std         5.405528
# min      1984.000000
# 25%      2009.000000
# 50%      2013.000000
# 75%      2016.000000
# max      2022.000000
# Name: Model year, dtype: float64

# %%
# Fill the missings withe the mean value
data['Model year'] =  data['Model year'].fillna(2012.0)

# Check the number of missings
data['Model year'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill the missings of Hand column**

# %%
# Create a new category of NaN values
data['Hand'] = data['Hand'].fillna('Not specified')

# Show changes
data['Hand'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in Mileage column**

# %%
# Fill the missings with the mean value
data['Mileage'] = data['Mileage'].fillna('148.795 km')

# check the Mileage column
data['Mileage'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in Fuel type column**

# %%
# Print the value counts
data['Fuel type'].value_counts()
# Out:
# Diesel        1898
# Essence        256
# Hybride          7
# Electrique       1
# Name: Fuel type, dtype: int64

# %%
# Fill the missing with the frequente value
data['Fuel type']  = data['Fuel type'].fillna('Not specified')

# Check the missings
data['Fuel type'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in Transmission column**

# %%
# Print the categories of Transmission
data['Transmission'].value_counts()
# Out:
# Manuelle       1145
# Automatique    1031
# Name: Transmission, dtype: int64

# %%
# Create new category for missing values
data['Transmission'] = data['Transmission'].fillna('Not specified')

# Check changes
data['Transmission'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill the missings in 'Exterior color' column**

# %%
# Show the different vehicule's colors 
data['Exterior color'].value_counts()
# Out:
# Noir             617
# Blanc            279
# Gris foncé       224
# Gris             221
# -                217
# Gris clair       155
# Bleu foncé        87
# Autre couleur     67
# Marron            50
# Bleu              49
# Rouge             47
# Beige             31
# Blanc cassé       24
# Bleu ciel         23
# Bordeau           21
# Marron clair      17
# Vert foncé        13
# Jaune d'or        10
# Violet             9
# Vert               9
# Orange             2
# Jaune              2
# Rose               2
# Name: Exterior color, dtype: int64

# %% [markdown]
# We have a 'Autre couleur' category. So, we can join the missings to this cotegory since every vehicule has a color

# %%
# Fill the missings with 'Autre couleur'
data['Exterior color']  = data['Exterior color'].fillna('Autre couleur')

# Replace the '-' category with 'Autre couleur'
data['Exterior color'] = data['Exterior color'].replace('-','Autre couleur')

# Check the missings
data['Exterior color'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in Vehicule condition column**

# %%
data['Vehicle condition'].value_counts()
# Out:
# Excellent      738
# Très bon       549
# Comme neuve    519
# -              219
# Bon            132
# Correct         19
# Name: Vehicle condition, dtype: int64

# %% [markdown]
# As we can say above, there is a category of '-' which means that the vehicle is not described. So, we can replace it with the NaN values with a new cotergory 'Not described'

# %%
# Fill the missings
data['Vehicle condition'] = data['Vehicle condition'].fillna('Not described')

# Change the '-' category
data['Vehicle condition'] =data['Vehicle condition'].replace('-', 'Not described')

# Check the changes
data['Vehicle condition'].value_counts()
# Out:
# Not described    1068
# Excellent         738
# Très bon          549
# Comme neuve       519
# Bon               132
# Correct            19
# Name: Vehicle condition, dtype: int64

# %% [markdown]
# 'Not described' category has 1068 entries, what was '-' and NaN

# %% [markdown]
# **Fill missings in 'Automatic trunk opening' column**

# %% [markdown]
# Since cars with the same brand and model share many similarities, we affect to missings in 'Automatic trunk opening' with the values of rows with the same brand and model.

# %%
# Create new category 'Not specified' for missing values 
data['Automatic trunk opening'] = data['Automatic trunk opening'].fillna('Not specified')

#Check changes
data['Automatic trunk opening'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in 'Engine architecture' column**

# %%
# Create new category for missing values
data['Engine architecture'] = data['Engine architecture'].fillna('Not specified')

# Check changes
data['Engine architecture'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in 'Engine displacement' column**

# %%
# Fill the missings with the mean value (this value is found in the data type problems)
data['Engine displacement'] = data['Engine displacement'].fillna('2007.43 cm³')

# check the Mileage column
data['Engine displacement'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in 'City fuel consumption' column**

# %%
# Fill the missings with the mean value (this value is found in the data type problems)
data['City fuel consumption'] = data['City fuel consumption'].fillna('6,6 l/100 km')

# check the Mileage column
data['Highway fuel consumption'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in 'Highway fuel consumption' column**

# %%
# Fill the missings with the mean value (this value is found in the data type problems)
data['Highway fuel consumption'] = data['Highway fuel consumption'].fillna('4,88 l/100 km')

# check the Mileage column
data['Highway fuel consumption'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in 'Maximun speed' column**

# %%
# Fill the missings with the mean value (this value is found in the data type problems)
data['Maximum speed'] = data['Maximum speed'].fillna('2009 km/h')

# check the Mileage column
data['Maximum speed'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Fill missings in 'Fuel tank volume' column**

# %%
# Fill the missings with the mean value (this value is found in the data type problems)
data['Fuel tank volume'] = data['Fuel tank volume'].fillna('58 litre')

# check the Mileage column
data['Fuel tank volume'].isna().sum()
# Out:
# 0

# %% [markdown]
# <h2 style="color: blue">Data type problems </h2>

# %% [markdown]
# <h3 style="color: purple">Task 1:</h3> Remove 'DH' or 'DH VENDUE' from Price and convert it to float and create a column that indicated if a vehicule is sold or not.

# %%
# Create a column named 'Sold' where we give 'oui' if the car is 'VENDUE' and 'non' if not
data['Price'] = data['Price'].astype('str')
data['Sold'] = data['Price'].apply(lambda x: 'oui' if len(x.split()) > 2 and x.split()[2] == "VENDUE" else 'non')

# Count of every category
print(data['Sold'].value_counts())

# Show changes
data.head()
# Out:
# non    1955
# oui    1070
# Name: Sold, dtype: int64
#       Brand           Model        Version       Price  Model year     Hand  \
# 0  MERCEDES   Classe C 2014          220 d  228.000 DH      2014.0  Seconde
# 1  MERCEDES   Classe C 2003        220 CDI   79.000 DH      2003.0  Seconde
# 2  MERCEDES   Classe B 2013    180 d Urban  150.000 DH      2013.0  Seconde
# 3  MERCEDES   Classe E 2006  Autre version  135.000 DH      2006.0  Seconde
# 4  MERCEDES  CLA Coupé 2014        220 CDI  240.000 DH      2014.0  Seconde
#
#       Mileage Fuel type Transmission Fiscal horsepower Exterior color  \
# 0  144.500 km    Diesel  Automatique              8 cv     Gris foncé
# 1  350.000 km    Diesel     Manuelle              8 cv           Noir
# 2  144.000 km    Diesel     Manuelle              8 cv           Noir
# 3  248.000 km    Diesel  Automatique              9 cv     Gris clair
# 4  103.000 km    Diesel  Automatique              9 cv    Blanc cassé
#
#   Vehicle condition Air conditioning  Electric windows  \
# 0          Très bon    auto. Bi-zone  Electrique AV/AR
# 1          Très bon            auto.  Electrique AV/AR
# 2       Comme neuve         manuelle  Electrique AV/AR
# 3       Comme neuve    auto. Bi-zone  Electrique AV/AR
# 4         Excellent            auto.  Electrique AV/AR
#
#            Electric seats On-board computer Start & Stop Cruise control  \
# 0  Conducteur et Passager               oui          oui            oui
# 1      Tous les passagers               oui          oui            oui
# 2                     non               oui          non            oui
# 3  Conducteur et Passager               oui          non            oui
# 4  Conducteur et Passager               oui          oui            oui
#
#   Automatic headlights Rain sensor Steering wheel controls  \
# 0                  oui         oui                     oui
# 1                  oui         oui                     oui
# 2                  oui         oui                     oui
# 3                  oui         oui                     oui
# 4                  oui         oui                     oui
#
#   Touchscreen display Electric mirrors Automatic trunk opening  \
# 0                 non              non                     non
# 1                 oui              oui                     oui
# 2                 non              non                     non
# 3                 non              oui                     oui
# 4                 non              oui                     non
#
#   Hands-free start 1/3-2/3 folding rear seat Backup camera Bluetooth  \
# 0              oui                       oui           oui       oui
# 1              non                       non           oui       oui
# 2              oui                       oui           oui       oui
# 3              oui                       non           non       oui
# 4              oui                       non           oui       oui
#
#   Aluminum wheels Leather steering wheel Daytime running lights Roof rails  \
# 0             oui                    oui                    oui        non
# 1             oui                    non                    oui        non
# 2             oui                    oui                    oui        non
# 3             oui                    non                    oui        oui
# 4             oui                    non                    oui        non
#
#           Roof Airbags  ABS  ESP Traction control Engine architecture  \
# 0       Rigide     oui  oui  oui              oui                 NaN
# 1       Rigide     oui  oui  oui              oui                 NaN
# 2       Rigide     oui  oui  oui              oui                 NaN
# 3       Rigide     oui  oui  oui              oui                 NaN
# 4  Panoramique     oui  oui  oui              oui                 NaN
#
#   Engine displacement City fuel consumption Highway fuel consumption  \
# 0                 NaN                   NaN                      NaN
# 1                 NaN                   NaN                      NaN
# 2                 NaN                   NaN                      NaN
# 3                 NaN                   NaN                      NaN
# 4                 NaN                   NaN                      NaN
#
#   Maximum speed Fuel tank volume Sold
# 0           NaN              NaN  non
# 1           NaN              NaN  non
# 2           NaN              NaN  non
# 3           NaN              NaN  non
# 4           NaN              NaN  non

# %%
# # Remove 'DH' or 'DH VENDUE' from 'Price'
# data['Price'] = data['Price'].str.split().str.get(0)
# data['Price'] = data['Price'].str.replace('.','')

# data['Price'].head()

# %%
# # Convert price to float
# data['Price'] = data['Price'].astype('float')

# # Show changes
# data['Price'].dtypes

# %% [markdown]
# <h3 style="color: purple">Task 2:</h3>Remove km from Mileage and convert it to float

# %%
# Remove 'km' and '.' from Mileage column 
data['Mileage'] = data['Mileage'].str.strip('km').str.replace('.','') 

#show changes
data['Mileage'].head()

# %%
# Convert 'Mileage' to float
data['Mileage'] = data['Mileage'].astype('float')

# Show the new type of 'Mileage' column
data['Mileage'].dtypes

# %% [markdown]
# <h3 style="color: purple">Task 6:</h3> Convert `Maximun speed` to float

# %%
# data['Maximum speed'].value_counts()
